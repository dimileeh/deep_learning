# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
train_words = []
words_freqs = Counter(int_words)

def drop_prob(t, freq):
    return 1 - np.sqrt(t/freq)

for word in int_words:
    drop = drop_prob(1e-5, words_freqs[word]/len(int_words))
    if drop < random.random():
        train_words.append(word)

# %%
len(train_words)
# Out:
# 4629559

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randrange(1, window_size+1)
    
    start_idx = idx - r if (idx - r) > 0 else 0
    stop_idx = idx + r
    
    window = words[start_idx:idx] + words[idx+1:stop_idx]
    
    return window

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    # create softmax biases here                        
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6070 0.1728 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5583 0.1695 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4794 0.1772 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5404 0.1626 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4589 0.1594 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5008 0.1652 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5456 0.1640 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4888 0.1847 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4234 0.1638 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3601 0.1596 sec/batch
# Nearest to all: grover, engel, adjacent, pterodroma, beazley, geocachers, factional, surpluses,
# Nearest to while: hangovers, acceptable, shortwave, advancements, laver, appeasing, memorial, archetype,
# Nearest to would: farsi, logistics, collides, majdanek, abramovich, nederlandse, hotter, ellipsoid,
# Nearest to not: singaporean, isp, dedicate, reiterated, ethiopia, educate, refer, launching,
# Nearest to new: classical, bingo, easters, apertures, cuauht, gaeltacht, amendments, fearless,
# Nearest to or: gargoyle, centrioles, sampson, land, liouville, raf, heterogeneous, cartoonists,
# Nearest to up: atgm, jesu, avila, yell, nitroglycerin, credibility, descendants, benny,
# Nearest to than: titular, mermaid, denominated, shaffer, fermilab, chanting, yob, prerecorded,
# Nearest to institute: formations, kindergarten, zweibr, indebted, biotechnology, salvaged, sedative, shuttle,
# Nearest to rise: settle, apotheosis, validly, bes, beavis, caen, impotent, miscarriage,
# Nearest to numerous: fitter, vong, hardcover, smear, global, trolling, substance, guerillas,
# Nearest to versions: psk, universalists, cabal, litter, centurion, keller, snatch, proprioception,
# Nearest to alternative: likelihood, taganrog, ventilated, outfielders, ganges, bartley, truck, ath,
# Nearest to units: fires, defrauding, planar, swordsmen, multipole, weymouth, maige, lacquer,
# Nearest to mainly: csrt, humanly, nudie, provides, context, fisk, naas, cb,
# Nearest to recorded: complement, jang, iommi, beaux, hypotension, mycological, lachish, adoptive,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4985 0.1636 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3614 0.1809 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3220 0.1715 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2371 0.1642 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1975 0.1727 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1947 0.1638 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1280 0.1672 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0864 0.1862 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0344 0.1841 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0085 0.1626 sec/batch
# Nearest to all: adjacent, differ, scope, engel, surpluses, constituting, pterodroma, sam,
# Nearest to while: acceptable, hangovers, precisely, archetype, shortwave, advancements, memorial, diary,
# Nearest to would: logistics, cards, nation, officer, farsi, age, tortured, majdanek,
# Nearest to not: refer, singaporean, isp, ethiopia, educate, reiterated, dedicate, peano,
# Nearest to new: classical, easters, apertures, bingo, ie, amendments, if, cuauht,
# Nearest to or: land, centrioles, you, cartoonists, let, heterogeneous, raf, liouville,
# Nearest to up: atgm, credibility, nitroglycerin, needed, fail, parameters, paid, descendants,
# Nearest to than: writings, chanting, titular, no, shaffer, mermaid, likes, prerecorded,
# Nearest to institute: formations, compression, make, kindergarten, zweibr, indebted, shuttle, sedative,
# Nearest to rise: settle, validly, diameter, bes, beavis, apotheosis, number, exit,
# Nearest to numerous: fitter, global, hardcover, number, player, vong, web, substance,
# Nearest to versions: psk, universalists, cabal, posts, offenders, keller, litter, hellenistic,
# Nearest to alternative: likelihood, respect, ended, stop, truck, eclecticism, ventilated, bartley,
# Nearest to units: fires, provides, planar, distance, weymouth, therefore, multipole, free,
# Nearest to mainly: csrt, context, provides, humanly, nudie, cb, fisk, approaching,
# Nearest to recorded: complement, jang, iommi, society, adoptive, mycological, beaux, hypotension,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9526 0.1666 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9110 0.1695 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9006 0.1611 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8902 0.1629 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7994 0.1620 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8374 0.1671 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7925 0.1681 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8123 0.1663 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7838 0.1724 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8009 0.1684 sec/batch
# Nearest to all: adjacent, differ, grover, enables, engel, pterodroma, scope, surpluses,
# Nearest to while: acceptable, shortwave, precisely, archetype, hangovers, advancements, memorial, charge,
# Nearest to would: logistics, farsi, nation, majdanek, hotter, officer, cards, tortured,
# Nearest to not: refer, dedicate, educate, peano, isp, singaporean, decreased, ethiopia,
# Nearest to new: classical, bingo, easters, apertures, ie, amendments, outsiders, campo,
# Nearest to or: centrioles, land, raf, gargoyle, heterogeneous, advertisements, scanning, grammars,
# Nearest to up: descendants, credibility, atgm, paid, needed, parameters, nitroglycerin, fail,
# Nearest to than: writings, titular, likes, chanting, denominated, send, keyboard, evils,
# Nearest to institute: formations, kindergarten, compression, shuttle, make, biotechnology, spreading, sedative,
# Nearest to rise: settle, apotheosis, validly, diameter, bes, aegean, beavis, philosophic,
# Nearest to numerous: fitter, hardcover, vong, touch, substance, guerillas, global, player,
# Nearest to versions: psk, universalists, keller, centurion, litter, cabal, hellenistic, smallest,
# Nearest to alternative: likelihood, respect, ended, contained, labeled, truck, eclecticism, stop,
# Nearest to units: fires, provides, planar, multipole, distance, weymouth, defrauding, szeged,
# Nearest to mainly: csrt, context, humanly, provides, nudie, fisk, utilities, luxembourg,
# Nearest to recorded: complement, jang, iommi, society, hypotension, adoptive, beaux, mycological,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7720 0.1666 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7723 0.1696 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7113 0.1671 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7102 0.1647 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7757 0.1662 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7226 0.1689 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7176 0.1666 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7280 0.1642 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7148 0.1619 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6518 0.1710 sec/batch
# Nearest to all: adjacent, grover, engel, differ, enables, punitive, pterodroma, meritorious,
# Nearest to while: acceptable, archetype, shortwave, hangovers, memorial, advancements, appeasing, precisely,
# Nearest to would: logistics, farsi, hotter, majdanek, nation, ellipsoid, proving, idealistic,
# Nearest to not: dedicate, peano, refer, isp, educate, variability, decreased, natufian,
# Nearest to new: classical, bingo, apertures, easters, reggae, bibles, aide, elisabeth,
# Nearest to or: centrioles, heterogeneous, raf, gargoyle, land, liouville, grammars, scanning,
# Nearest to up: atgm, descendants, credibility, paid, fail, parameters, yell, needed,
# Nearest to than: titular, fermilab, likes, writings, denominated, chanting, evils, horns,
# Nearest to institute: biotechnology, formations, kindergarten, shuttle, compression, spreading, sedative, zweibr,
# Nearest to rise: settle, apotheosis, validly, bes, aegean, caen, impotent, beavis,
# Nearest to numerous: fitter, vong, guerillas, hardcover, trolling, meadow, smear, touch,
# Nearest to versions: psk, universalists, keller, centurion, litter, cabal, silmarillion, smallest,
# Nearest to alternative: likelihood, respect, eclecticism, manned, ventilated, truck, contained, labeled,
# Nearest to units: fires, planar, defrauding, provides, multipole, weymouth, swordsmen, anglia,
# Nearest to mainly: csrt, provides, humanly, nudie, context, utilities, fisk, cb,
# Nearest to recorded: complement, jang, iommi, hypotension, adoptive, beaux, society, disbelief,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6695 0.1767 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6537 0.1789 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6268 0.1658 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6279 0.1660 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6337 0.1625 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6378 0.1625 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6344 0.1159 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5509 0.1634 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5525 0.1629 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5116 0.1624 sec/batch
# Nearest to all: grover, engel, differ, adjacent, punitive, enables, pterodroma, meritorious,
# Nearest to while: acceptable, archetype, hangovers, advancements, shortwave, precisely, wedded, appeasing,
# Nearest to would: farsi, hotter, logistics, majdanek, proving, cabell, ellipsoid, legitimately,
# Nearest to not: refer, peano, dedicate, variability, resting, isp, bolster, should,
# Nearest to new: classical, bingo, reggae, humbled, bibles, easters, aide, elisabeth,
# Nearest to or: heterogeneous, gargoyle, centrioles, scanning, grammars, esquire, liouville, unfavourably,
# Nearest to up: atgm, paid, descendants, belligerent, credibility, nitroglycerin, fail, yell,
# Nearest to than: fermilab, titular, likes, denominated, send, sawdust, keyboard, chanting,
# Nearest to institute: biotechnology, formations, kindergarten, shuttle, compression, crean, sedative, april,
# Nearest to rise: settle, apotheosis, validly, impotent, bes, aegean, caen, miscarriage,
# Nearest to numerous: fitter, vong, meadow, guerillas, hardcover, smear, touch, landen,
# Nearest to versions: universalists, psk, keller, silmarillion, smallest, parliamentarians, folks, glissandi,
# Nearest to alternative: likelihood, respect, correlated, ganges, cortex, contained, labeled, ventilated,
# Nearest to units: fires, defrauding, planar, multipole, provides, bethany, amazing, si,
# Nearest to mainly: csrt, provides, context, nudie, humanly, naas, fisk, ucla,
# Nearest to recorded: complement, jang, iommi, hypotension, beaux, adoptive, glas, disbelief,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4748 0.1707 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5081 0.1626 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4605 0.1677 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5317 0.1733 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4973 0.2008 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4810 0.1914 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4444 0.1971 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4046 0.1900 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4457 0.1914 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4381 0.1920 sec/batch
# Nearest to all: grover, differ, engel, punitive, enables, adjacent, meritorious, pterodroma,
# Nearest to while: acceptable, hangovers, wedded, advancements, precisely, archetype, appeasing, tremble,
# Nearest to would: logistics, hotter, farsi, majdanek, nation, cabell, puritanism, af,
# Nearest to not: refer, peano, dedicate, resting, variability, uninfected, should, meditations,
# Nearest to new: bingo, classical, reggae, aide, elisabeth, easters, humbled, apertures,
# Nearest to or: heterogeneous, grammars, centrioles, unfavourably, gargoyle, properties, spiritually, scanning,
# Nearest to up: atgm, belligerent, paid, fail, bikini, credibility, avila, descendants,
# Nearest to than: fermilab, titular, kilo, likes, sawdust, secondary, denominated, publicize,
# Nearest to institute: biotechnology, kindergarten, crean, shuttle, formations, april, paget, compression,
# Nearest to rise: settle, apotheosis, impotent, bes, caen, validly, miscarriage, aegean,
# Nearest to numerous: fitter, vong, guerillas, meadow, global, landen, hardcover, alh,
# Nearest to versions: universalists, psk, smallest, silmarillion, keller, parliamentarians, encephalopathy, glissandi,
# Nearest to alternative: likelihood, correlated, ventilated, contained, ganges, labeled, respect, eclecticism,
# Nearest to units: defrauding, fires, provides, zero, multipole, distance, planar, si,
# Nearest to mainly: csrt, provides, redox, nudie, naas, humanly, context, myanmar,
# Nearest to recorded: iommi, complement, jang, beaux, adoptive, hypotension, glas, disbelief,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4253 0.1971 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4449 0.1926 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4298 0.1901 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3798 0.1927 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3886 0.1871 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4332 0.1868 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3630 0.1878 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3720 0.1894 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3936 0.1882 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3558 0.1956 sec/batch
# Nearest to all: grover, differ, punitive, enables, engel, meritorious, scope, pterodroma,
# Nearest to while: acceptable, hangovers, archetype, wedded, tremble, appeasing, precisely, advancements,
# Nearest to would: logistics, farsi, hotter, af, majdanek, alemannic, cabell, mond,
# Nearest to not: refer, should, meditations, resting, peano, dedicate, variability, uninfected,
# Nearest to new: bingo, reggae, classical, aide, olbers, bibles, valign, elisabeth,
# Nearest to or: heterogeneous, grammars, centrioles, unfavourably, gargoyle, liouville, able, spiritually,
# Nearest to up: atgm, needed, fail, bikini, belligerent, credibility, nitroglycerin, worn,
# Nearest to than: fermilab, secondary, sawdust, titular, likes, kilo, denominated, evils,
# Nearest to institute: biotechnology, crean, kindergarten, april, paget, shuttle, tompkins, compression,
# Nearest to rise: settle, apotheosis, impotent, validly, caen, aegean, bes, slumber,
# Nearest to numerous: fitter, vong, meadow, guerillas, hardcover, tirana, electromechanical, landen,
# Nearest to versions: universalists, psk, keller, silmarillion, simulation, glissandi, hardware, parliamentarians,
# Nearest to alternative: likelihood, correlated, respect, labeled, taganrog, eclecticism, ventilated, contained,
# Nearest to units: defrauding, planar, multipole, si, fires, zero, distance, crux,
# Nearest to mainly: csrt, redox, naas, myanmar, nudie, humanly, provides, curbing,
# Nearest to recorded: iommi, complement, beaux, jang, hypotension, adoptive, glas, alien,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3762 0.1928 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3730 0.1858 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3682 0.1864 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3643 0.1873 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3850 0.1887 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3727 0.1937 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3651 0.1894 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3903 0.1922 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3263 0.1910 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3099 0.1917 sec/batch
# Nearest to all: grover, punitive, differ, engel, enables, meritorious, transverse, is,
# Nearest to while: acceptable, hangovers, archetype, appeasing, wedded, laver, tremble, advancements,
# Nearest to would: logistics, farsi, puritanism, mond, pesky, legitimately, hotter, alemannic,
# Nearest to not: meditations, resting, aspirations, should, dedicate, peano, variability, refer,
# Nearest to new: bingo, reggae, classical, valign, bibles, easters, cusick, prepares,
# Nearest to or: heterogeneous, grammars, unfavourably, centrioles, liouville, spiritually, able, coprophagia,
# Nearest to up: atgm, fail, nitroglycerin, bikini, belligerent, needed, avila, worn,
# Nearest to than: fermilab, secondary, sawdust, shirow, titular, uptime, denominated, likes,
# Nearest to institute: biotechnology, crean, kindergarten, paget, tompkins, shuttle, april, paramount,
# Nearest to rise: apotheosis, settle, impotent, validly, caen, bes, aegean, slumber,
# Nearest to numerous: fitter, meadow, vong, electromechanical, guerillas, landen, alh, stuyvesant,
# Nearest to versions: universalists, psk, silmarillion, safari, simulation, keller, unix, hardware,
# Nearest to alternative: likelihood, correlated, labeled, yezhov, contained, taganrog, cortex, eclecticism,
# Nearest to units: defrauding, zero, multipole, planar, si, fires, crux, internally,
# Nearest to mainly: csrt, myanmar, redox, naas, emigrants, curbing, northumbrians, humanly,
# Nearest to recorded: iommi, adoptive, beaux, hypotension, jang, complement, glas, alien,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3326 0.1827 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3185 0.1981 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3697 0.2210 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3382 0.2235 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3844 0.2196 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2643 0.2223 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3279 0.2202 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2926 0.2275 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2085 0.2229 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2944 0.2224 sec/batch
# Nearest to all: grover, punitive, engel, differ, pterodroma, replays, enables, pooh,
# Nearest to while: wedded, hangovers, acceptable, archetype, appeasing, tremble, laver, maddux,
# Nearest to would: logistics, farsi, majdanek, pesky, proving, ellipsoid, puritanism, cabell,
# Nearest to not: should, resting, meditations, peano, variability, aspirations, refer, whatever,
# Nearest to new: reggae, bingo, bibles, cusick, valign, aide, national, easters,
# Nearest to or: heterogeneous, unfavourably, grammars, gargoyle, liouville, centrioles, coprophagia, able,
# Nearest to up: atgm, bikini, fail, nitroglycerin, worn, belligerent, avila, descendants,
# Nearest to than: fermilab, sawdust, shirow, secondary, denominated, titular, kilo, uptime,
# Nearest to institute: biotechnology, crean, paget, sciences, kindergarten, tompkins, association, drabble,
# Nearest to rise: apotheosis, settle, impotent, validly, caen, bes, slumber, aegean,
# Nearest to numerous: fitter, meadow, guerillas, electromechanical, global, vong, tirana, alh,
# Nearest to versions: universalists, psk, silmarillion, unix, simulation, hardware, safari, keller,
# Nearest to alternative: likelihood, correlated, yezhov, labeled, differentiable, contained, respect, casteljau,
# Nearest to units: si, defrauding, multipole, planar, zero, crux, fires, downwind,
# Nearest to mainly: csrt, myanmar, curbing, redox, naas, nudie, emigrants, humanly,
# Nearest to recorded: iommi, adoptive, beaux, hypotension, jang, complement, grossing, alien,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2657 0.2249 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3039 0.2200 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3369 0.0912 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2207 0.2166 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2263 0.2182 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1903 0.2177 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2029 0.2195 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1875 0.2259 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2007 0.2141 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1769 0.2148 sec/batch
# Nearest to all: grover, punitive, engel, pterodroma, differ, replays, enables, pooh,
# Nearest to while: acceptable, hangovers, tremble, wedded, appeasing, archetype, advancements, mamie,
# Nearest to would: mond, pesky, farsi, logistics, majdanek, when, unsuccessfully, recumbent,
# Nearest to not: resting, should, meditations, multifinder, reiterated, variability, may, adoption,
# Nearest to new: bingo, reggae, national, valign, bibles, cusick, seneca, classical,
# Nearest to or: heterogeneous, unfavourably, grammars, coprophagia, gargoyle, liouville, thereof, centrioles,
# Nearest to up: atgm, bikini, worn, nitroglycerin, belligerent, fail, wiser, needed,
# Nearest to than: fermilab, sawdust, shirow, uptime, secondary, kilo, titular, denominated,
# Nearest to institute: biotechnology, sciences, crean, association, paget, kindergarten, tompkins, drabble,
# Nearest to rise: apotheosis, settle, impotent, caen, validly, aegean, slumber, bes,
# Nearest to numerous: fitter, meadow, global, electromechanical, guerillas, vong, entirely, tirana,
# Nearest to versions: psk, universalists, safari, silmarillion, unix, hardware, itanium, proprietary,
# Nearest to alternative: likelihood, wysiwyg, correlated, yezhov, labeled, ventilated, taganrog, contained,
# Nearest to units: si, defrauding, zero, multipole, planar, crux, helicopters, internally,
# Nearest to mainly: csrt, myanmar, redox, nudie, curbing, emigrants, naas, includes,
# Nearest to recorded: iommi, complement, beaux, adoptive, hypotension, grossing, jang, alien,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2137 0.2190 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1938 0.2023 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1827 0.1815 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0964 0.2265 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1258 0.2164 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1424 0.2189 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1343 0.2174 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1552 0.2199 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2029 0.2204 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1299 0.1836 sec/batch
# Nearest to all: grover, punitive, pterodroma, enables, replays, differ, engel, laterals,
# Nearest to while: hangovers, acceptable, appeasing, precisely, wedded, tremble, turbulence, advancements,
# Nearest to would: pesky, mond, logistics, recumbent, farsi, cabell, majdanek, subsists,
# Nearest to not: whatever, should, meditations, may, resting, multifinder, variability, jarring,
# Nearest to new: national, reggae, bingo, librarianship, easters, bibles, seneca, cusick,
# Nearest to or: heterogeneous, unfavourably, grammars, gargoyle, blueberries, liouville, coprophagia, centrioles,
# Nearest to up: atgm, worn, nitroglycerin, bikini, fail, needed, belligerent, vcr,
# Nearest to than: fermilab, sawdust, shirow, kilo, uptime, secondary, titular, denominated,
# Nearest to institute: biotechnology, sciences, association, crean, community, tompkins, paget, tech,
# Nearest to rise: apotheosis, settle, impotent, slumber, caen, validly, aegean, bubi,
# Nearest to numerous: fitter, meadow, entirely, guerillas, global, electromechanical, stuyvesant, web,
# Nearest to versions: psk, universalists, safari, silmarillion, unix, workstation, keller, simons,
# Nearest to alternative: likelihood, wysiwyg, yezhov, labeled, correlated, taganrog, dmc, contained,
# Nearest to units: si, planar, defrauding, zero, multipole, helicopters, crux, internally,
# Nearest to mainly: csrt, curbing, redox, myanmar, nudie, humanly, emigrants, flautist,
# Nearest to recorded: iommi, beaux, complement, alien, adoptive, sidekick, grossing, jang,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1619 0.2091 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2056 0.2012 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1605 0.2031 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1477 0.2009 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1446 0.2073 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1764 0.1970 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2073 0.1993 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1328 0.2001 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1176 0.2017 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1652 0.2028 sec/batch
# Nearest to all: grover, punitive, enables, replays, differ, laterals, pterodroma, meritorious,
# Nearest to while: appeasing, hangovers, acceptable, wedded, tremble, laver, corporatocracy, archetype,
# Nearest to would: pesky, mond, legitimately, unsuccessfully, majdanek, subsists, farsi, recumbent,
# Nearest to not: meditations, may, should, multifinder, variability, resting, heroism, fairness,
# Nearest to new: librarianship, reggae, butterfield, bibles, seneca, easters, national, cusick,
# Nearest to or: heterogeneous, unfavourably, grammars, liouville, centrioles, blueberries, gargoyle, tautological,
# Nearest to up: atgm, worn, nitroglycerin, bikini, fail, needed, vcr, tosses,
# Nearest to than: fermilab, shirow, uptime, sawdust, denominated, titular, secondary, kilo,
# Nearest to institute: biotechnology, sciences, association, crean, community, tompkins, departments, paget,
# Nearest to rise: apotheosis, settle, impotent, slumber, caen, validly, bubi, extreme,
# Nearest to numerous: fitter, meadow, entirely, electromechanical, guerillas, web, stuyvesant, smear,
# Nearest to versions: psk, universalists, safari, unix, keller, silmarillion, simons, proprietary,
# Nearest to alternative: likelihood, wysiwyg, labeled, correlated, yezhov, contained, casteljau, taganrog,
# Nearest to units: si, planar, multipole, defrauding, crux, zero, helicopters, internally,
# Nearest to mainly: csrt, emigrants, myanmar, curbing, nudie, bissau, redox, naas,
# Nearest to recorded: iommi, beaux, alien, grossing, adoptive, complement, sidekick, coronation,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1848 0.2112 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1457 0.1977 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1572 0.2017 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1752 0.1888 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1343 0.1631 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1174 0.1630 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1301 0.1640 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1105 0.1668 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1814 0.1607 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1973 0.1631 sec/batch
# Nearest to all: grover, punitive, differ, pterodroma, jewish, pooh, replays, ingush,
# Nearest to while: appeasing, hangovers, acceptable, wedded, archetype, mamie, stake, tremble,
# Nearest to would: pesky, unsuccessfully, mond, subsists, puritanism, when, farsi, legitimately,
# Nearest to not: meditations, may, adoption, reiterated, authorize, fairness, jarring, should,
# Nearest to new: reggae, seneca, bibles, librarianship, national, butterfield, easters, cusick,
# Nearest to or: heterogeneous, unfavourably, grammars, liouville, enjoys, illiniwek, tautological, coprophagia,
# Nearest to up: atgm, bikini, worn, avila, nitroglycerin, belligerent, fail, credibility,
# Nearest to than: shirow, denominated, fermilab, titular, verdun, uptime, kilo, sawdust,
# Nearest to institute: biotechnology, sciences, association, crean, departments, kindergarten, tompkins, community,
# Nearest to rise: apotheosis, impotent, settle, caen, bubi, slumber, validly, extreme,
# Nearest to numerous: fitter, meadow, entirely, electromechanical, stuyvesant, tirana, alh, guerillas,
# Nearest to versions: psk, safari, universalists, unix, rocker, keller, rabba, itanium,
# Nearest to alternative: yezhov, labeled, likelihood, wysiwyg, correlated, bartley, contained, taganrog,
# Nearest to units: si, planar, multipole, crux, defrauding, internally, helicopters, abidjan,
# Nearest to mainly: emigrants, csrt, curbing, myanmar, humanly, northumbrians, redox, nudie,
# Nearest to recorded: iommi, beaux, adoptive, grossing, alien, sidekick, philharmonic, coronation,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1890 0.1650 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1250 0.1623 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0953 0.1730 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1319 0.1650 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9900 0.1761 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1086 0.1603 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1238 0.1751 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1299 0.1630 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1336 0.0214 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1128 0.1615 sec/batch
# Nearest to all: grover, punitive, pterodroma, enables, engel, finishing, ingush, entangle,
# Nearest to while: appeasing, hangovers, acceptable, laver, archetype, stake, mamie, wedded,
# Nearest to would: pesky, mond, unsuccessfully, recumbent, farsi, subsists, motive, majdanek,
# Nearest to not: multifinder, may, meditations, adoption, jarring, authorize, variability, clown,
# Nearest to new: reggae, national, bibles, cusick, kickstart, seneca, lune, butterfield,
# Nearest to or: heterogeneous, unfavourably, grammars, gargoyle, enjoys, illiniwek, liouville, coprophagia,
# Nearest to up: atgm, nitroglycerin, worn, bikini, fail, belligerent, yell, descendants,
# Nearest to than: denominated, fermilab, shirow, kilo, uptime, titular, sawdust, demodulation,
# Nearest to institute: biotechnology, sciences, association, departments, kindergarten, crean, loyola, paget,
# Nearest to rise: apotheosis, impotent, settle, caen, extreme, bubi, validly, slumber,
# Nearest to numerous: fitter, meadow, gauze, entirely, electromechanical, tirana, nasty, smear,
# Nearest to versions: universalists, psk, safari, itanium, workstation, newer, unix, proprietary,
# Nearest to alternative: wysiwyg, yezhov, likelihood, labeled, contained, correlated, dmc, casteljau,
# Nearest to units: si, planar, crux, multipole, defrauding, helicopters, unit, internally,
# Nearest to mainly: csrt, emigrants, curbing, myanmar, proto, humanly, context, northumbrians,
# Nearest to recorded: iommi, grossing, adoptive, beaux, philharmonic, alien, coronation, sidekick,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0385 0.1660 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0856 0.1681 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0590 0.1594 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0216 0.1619 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0358 0.1642 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0150 0.1643 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0854 0.1624 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0718 0.1631 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0630 0.1645 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0236 0.1680 sec/batch
# Nearest to all: grover, enables, finishing, punitive, woz, entangle, ruffini, laterals,
# Nearest to while: hangovers, appeasing, acceptable, archetype, precisely, mamie, tremble, laver,
# Nearest to would: pesky, unsuccessfully, mond, abramovich, recumbent, subsists, upwardly, kickoff,
# Nearest to not: multifinder, adoption, may, their, meditations, jarring, authorize, accomplice,
# Nearest to new: bibles, seneca, kickstart, ideographic, easters, packard, national, valign,
# Nearest to or: heterogeneous, unfavourably, grammars, coprophagia, gargoyle, illiniwek, enjoys, multiples,
# Nearest to up: atgm, worn, bikini, nitroglycerin, yell, needed, belligerent, fail,
# Nearest to than: denominated, titular, shirow, uptime, fermilab, kilo, secondary, gull,
# Nearest to institute: biotechnology, association, sciences, departments, colleges, tech, kindergarten, community,
# Nearest to rise: apotheosis, impotent, bubi, caen, settle, extreme, validly, sortavala,
# Nearest to numerous: fitter, meadow, entirely, electromechanical, web, nasty, hardcover, smear,
# Nearest to versions: psk, universalists, silmarillion, safari, newer, keller, rabba, simons,
# Nearest to alternative: wysiwyg, yezhov, labeled, likelihood, correlated, bartley, dmc, taganrog,
# Nearest to units: si, planar, multipole, crux, unit, zero, internally, helicopters,
# Nearest to mainly: csrt, curbing, emigrants, myanmar, flautist, context, linings, proto,
# Nearest to recorded: iommi, beaux, grossing, philharmonic, adoptive, whispering, coronation, alien,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9818 0.2049 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9800 0.2031 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9624 0.2007 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0153 0.1998 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0249 0.2028 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0502 0.2051 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0141 0.1998 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0671 0.1998 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0354 0.2021 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0289 0.2002 sec/batch
# Nearest to all: grover, enables, punitive, finishing, is, laterals, ruffini, woz,
# Nearest to while: hangovers, appeasing, precisely, acceptable, archetype, turbulence, audiophiles, wedded,
# Nearest to would: pesky, unsuccessfully, mond, motive, subsists, legitimately, abramovich, recumbent,
# Nearest to not: may, accomplice, multifinder, meditations, adoption, clown, jarring, aspirations,
# Nearest to new: bibles, lune, seneca, butterfield, national, packard, york, easters,
# Nearest to or: heterogeneous, unfavourably, grammars, gargoyle, multiples, liouville, blueberries, illiniwek,
# Nearest to up: atgm, worn, bikini, yell, nitroglycerin, needed, tosses, qos,
# Nearest to than: denominated, fermilab, kilo, titular, shirow, uptime, sawdust, secondary,
# Nearest to institute: biotechnology, sciences, association, departments, community, loyola, kindergarten, tompkins,
# Nearest to rise: apotheosis, impotent, bubi, caen, settle, slumber, extreme, orbital,
# Nearest to numerous: fitter, meadow, entirely, electromechanical, web, hardcover, tirana, nasty,
# Nearest to versions: newer, psk, silmarillion, universalists, rabba, rocker, safari, simons,
# Nearest to alternative: wysiwyg, yezhov, labeled, likelihood, correlated, nlm, bartley, taganrog,
# Nearest to units: si, planar, multipole, unit, internally, crux, together, defrauding,
# Nearest to mainly: csrt, curbing, emigrants, myanmar, proto, linings, northumbrians, redox,
# Nearest to recorded: iommi, philharmonic, whispering, alien, grossing, coronation, adoptive, absorption,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0093 0.2004 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0589 0.1924 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0476 0.2002 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0245 0.2021 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0474 0.2018 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0273 0.2019 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0262 0.2080 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0080 0.1885 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0742 0.2035 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0250 0.1994 sec/batch
# Nearest to all: grover, enables, punitive, finishing, is, constituting, apocalypses, ruffini,
# Nearest to while: appeasing, hangovers, precisely, acceptable, archetype, contagious, wedded, tremble,
# Nearest to would: unsuccessfully, pesky, mond, legitimately, isaac, nation, abramovich, caiman,
# Nearest to not: accomplice, jarring, meditations, may, adoption, prayer, multifinder, aspirations,
# Nearest to new: bibles, seneca, lune, york, packard, butterfield, easters, librarianship,
# Nearest to or: unfavourably, heterogeneous, grammars, enjoys, illiniwek, multiples, liouville, centrioles,
# Nearest to up: atgm, bikini, yell, worn, avila, ipkf, nitroglycerin, credibility,
# Nearest to than: denominated, kilo, fermilab, verdun, shirow, uptime, titular, capacities,
# Nearest to institute: biotechnology, association, sciences, departments, loyola, kindergarten, tompkins, community,
# Nearest to rise: apotheosis, impotent, bubi, caen, extreme, settle, sortavala, mankiewicz,
# Nearest to numerous: fitter, entirely, electromechanical, meadow, chevron, nasty, hardcover, nilgiri,
# Nearest to versions: newer, psk, silmarillion, rocker, rabba, itanium, universalists, simons,
# Nearest to alternative: wysiwyg, yezhov, labeled, likelihood, casteljau, correlated, contained, bartley,
# Nearest to units: si, planar, multipole, unit, crux, internally, together, abidjan,
# Nearest to mainly: csrt, curbing, myanmar, emigrants, northumbrians, proto, transliterator, brahui,
# Nearest to recorded: iommi, philharmonic, whispering, grossing, coronation, session, adoptive, beaux,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0427 0.2012 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9551 0.2025 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9807 0.2082 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0487 0.1994 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0237 0.1998 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1068 0.2017 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0694 0.2012 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0320 0.2108 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9838 0.2207 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0175 0.2171 sec/batch
# Nearest to all: grover, punitive, finishing, enables, apocalypses, constituting, ruffini, entangle,
# Nearest to while: appeasing, hangovers, precisely, wedded, mamie, acceptable, contagious, corporatocracy,
# Nearest to would: unsuccessfully, pesky, mond, isaac, legitimately, abramovich, caiman, bakesperson,
# Nearest to not: accomplice, may, meditations, adoption, knows, authorize, jarring, clown,
# Nearest to new: bibles, seneca, york, lune, butterfield, cardozo, cusick, confederate,
# Nearest to or: unfavourably, heterogeneous, grammars, gargoyle, vowel, illiniwek, liouville, multiples,
# Nearest to up: atgm, bikini, worn, yell, avila, descendants, nitroglycerin, ipkf,
# Nearest to than: denominated, fermilab, shirow, kilo, verdun, titular, likes, compared,
# Nearest to institute: biotechnology, sciences, association, departments, tompkins, loyola, kindergarten, polytechnic,
# Nearest to rise: apotheosis, impotent, bubi, caen, extreme, tempering, mankiewicz, settle,
# Nearest to numerous: fitter, electromechanical, meadow, nilgiri, entirely, hardcover, chevron, nasty,
# Nearest to versions: rabba, psk, newer, silmarillion, rocker, itanium, folks, simons,
# Nearest to alternative: wysiwyg, labeled, yezhov, bartley, likelihood, eclecticism, sarabande, guimar,
# Nearest to units: si, planar, multipole, unit, internally, crux, abidjan, together,
# Nearest to mainly: csrt, curbing, myanmar, emigrants, transliterator, northumbrians, proto, linings,
# Nearest to recorded: philharmonic, iommi, whispering, album, grossing, coronation, goodbye, session,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9773 0.2119 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9592 0.1718 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0037 0.1827 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9768 0.1785 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0226 0.1790 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0178 0.1582 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9673 0.1754 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9472 0.1749 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9798 0.2025 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9177 0.2008 sec/batch
# Nearest to all: grover, apocalypses, punitive, finishing, ruffini, entangle, enables, auntie,
# Nearest to while: appeasing, hangovers, contagious, precisely, audiophiles, tremble, acceptable, knocks,
# Nearest to would: mond, unsuccessfully, pesky, isaac, legitimately, abramovich, cabell, upwardly,
# Nearest to not: accomplice, authorize, adoption, multifinder, meditations, jarring, may, needs,
# Nearest to new: bibles, york, seneca, packard, butterfield, lune, kickstart, valign,
# Nearest to or: heterogeneous, unfavourably, grammars, enjoys, coprophagia, gargoyle, vowel, illiniwek,
# Nearest to up: atgm, yell, bikini, worn, nitroglycerin, credibility, exoplanet, descendants,
# Nearest to than: denominated, kilo, capacities, fermilab, compared, titular, keyboard, older,
# Nearest to institute: biotechnology, association, sciences, departments, tompkins, loyola, polytechnic, tech,
# Nearest to rise: apotheosis, impotent, bubi, extreme, caen, tempering, settle, validly,
# Nearest to numerous: fitter, meadow, electromechanical, entirely, nilgiri, chevron, reinvention, hardcover,
# Nearest to versions: newer, rabba, itanium, psk, silmarillion, workstation, rocker, safari,
# Nearest to alternative: wysiwyg, labeled, yezhov, nlm, likelihood, bartley, eclecticism, casteljau,
# Nearest to units: si, planar, unit, multipole, crux, together, internally, abidjan,
# Nearest to mainly: csrt, curbing, linings, flautist, humanly, transliterator, context, proto,
# Nearest to recorded: philharmonic, iommi, whispering, session, coronation, goodbye, album, grossing,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9373 0.2056 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8957 0.2002 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9888 0.1843 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9857 0.1891 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9859 0.1805 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9903 0.2022 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8771 0.2037 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9185 0.2081 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8856 0.2003 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9050 0.2059 sec/batch
# Nearest to all: grover, finishing, punitive, every, enables, entangle, woz, apocalypses,
# Nearest to while: appeasing, hangovers, precisely, watered, knocks, contagious, tremble, significand,
# Nearest to would: mond, pesky, unsuccessfully, upwardly, abramovich, cabell, legitimately, hotter,
# Nearest to not: accomplice, paracompact, multifinder, adoption, meditations, prayer, jarring, clown,
# Nearest to new: bibles, york, seneca, eight, butterfield, floundered, easters, cardozo,
# Nearest to or: unfavourably, grammars, heterogeneous, blueberries, multiples, illiniwek, enjoys, coprophagia,
# Nearest to up: atgm, yell, worn, bikini, needed, credibility, ipkf, descendants,
# Nearest to than: denominated, older, kilo, compared, fermilab, gull, capacities, titular,
# Nearest to institute: biotechnology, association, sciences, departments, tompkins, community, iit, loyola,
# Nearest to rise: impotent, apotheosis, bubi, tempering, extreme, caen, validly, mankiewicz,
# Nearest to numerous: fitter, electromechanical, meadow, entirely, nilgiri, hardcover, chevron, alh,
# Nearest to versions: newer, rabba, psk, folks, silmarillion, workstation, rocker, itanium,
# Nearest to alternative: wysiwyg, labeled, yezhov, nlm, bartley, likelihood, eclecticism, casteljau,
# Nearest to units: si, planar, unit, multipole, together, internally, abidjan, five,
# Nearest to mainly: csrt, curbing, linings, myanmar, flautist, transliterator, emigrants, esplanade,
# Nearest to recorded: iommi, philharmonic, whispering, session, recording, goodbye, coronation, grossing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9550 0.2080 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9719 0.2025 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9384 0.2098 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9908 0.2004 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9944 0.2020 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9088 0.2024 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9363 0.2030 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9441 0.1943 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9385 0.1725 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9327 0.1703 sec/batch
# Nearest to all: grover, enables, every, is, punitive, finishing, apocalypses, entangle,
# Nearest to while: appeasing, hangovers, contagious, swing, corporatocracy, knocks, tremble, watered,
# Nearest to would: mond, unsuccessfully, pesky, abramovich, isaac, upwardly, inhomogeneities, bakesperson,
# Nearest to not: accomplice, may, jarring, meditations, emphatic, knows, but, clown,
# Nearest to new: bibles, york, seneca, cardozo, butterfield, coincided, kickstart, librarianship,
# Nearest to or: unfavourably, multiples, grammars, heterogeneous, a, liouville, illiniwek, enjoys,
# Nearest to up: atgm, yell, bikini, worn, credibility, needed, tosses, ipkf,
# Nearest to than: denominated, older, kilo, capacities, compared, fermilab, verdun, titular,
# Nearest to institute: biotechnology, association, sciences, departments, tompkins, iit, specialists, vocational,
# Nearest to rise: impotent, apotheosis, bubi, tempering, caen, sortavala, extreme, validly,
# Nearest to numerous: fitter, electromechanical, meadow, nilgiri, entirely, hardcover, chevron, web,
# Nearest to versions: rabba, newer, folks, silmarillion, rocker, psk, simons, etext,
# Nearest to alternative: wysiwyg, labeled, yezhov, nlm, bartley, sarabande, legendary, dearth,
# Nearest to units: si, planar, unit, multipole, internally, together, crux, keypad,
# Nearest to mainly: csrt, curbing, linings, flautist, emigrants, myanmar, transliterator, northumbrians,
# Nearest to recorded: philharmonic, iommi, recording, whispering, session, album, goodbye, grossing,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9956 0.1672 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9062 0.1750 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9501 0.1654 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9691 0.1707 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9371 0.1711 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9650 0.1706 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9350 0.1734 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9085 0.1634 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9188 0.1664 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9806 0.1665 sec/batch
# Nearest to all: grover, is, apocalypses, enables, entangle, punitive, uninhabited, finishing,
# Nearest to while: appeasing, contagious, hangovers, corporatocracy, swing, watered, audiophiles, wedded,
# Nearest to would: mond, unsuccessfully, pesky, abramovich, isaac, legitimately, inhomogeneities, cabell,
# Nearest to not: accomplice, may, jarring, authorize, but, adoption, knows, paracompact,
# ...
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 3.9118 0.1681 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.9694 0.0894 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.8830 0.1625 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9349 0.1624 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9017 0.1689 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.9035 0.1641 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.8767 0.1628 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.8831 0.1646 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.8684 0.1607 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9307 0.1622 sec/batch
# Nearest to all: grover, finishing, every, enables, is, entangle, apocalypses, ruffini,
# Nearest to while: appeasing, watered, contagious, swing, mcclellan, knocks, hangovers, radiguet,
# Nearest to would: unsuccessfully, mond, pesky, isaac, upwardly, abramovich, nation, when,
# Nearest to not: accomplice, emphatic, adoption, but, multifinder, may, paracompact, jarring,
# Nearest to new: york, bibles, seneca, coincided, packard, james, confederate, kickstart,
# Nearest to or: unfavourably, harrier, shipper, some, coprophagia, a, illiniwek, enjoys,
# Nearest to up: atgm, yell, their, descendants, bikini, credibility, worn, needed,
# Nearest to than: compared, capacities, more, denominated, less, kilo, verdun, gull,
# Nearest to institute: biotechnology, association, iit, sciences, specialists, vocational, loyola, tompkins,
# Nearest to rise: bubi, apotheosis, tempering, caen, impotent, extreme, sortavala, kushan,
# Nearest to numerous: fitter, nilgiri, electromechanical, meadow, deporting, entirely, reinvention, masala,
# Nearest to versions: rabba, newer, folks, silmarillion, psk, etext, caml, workstation,
# Nearest to alternative: wysiwyg, nlm, yezhov, labeled, bartley, dearth, sarabande, casteljau,
# Nearest to units: si, unit, planar, multipole, together, internally, five, three,
# Nearest to mainly: linings, curbing, csrt, flautist, context, ottokar, transliterator, proto,
# Nearest to recorded: iommi, philharmonic, recording, whispering, session, track, album, grossing,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9193 0.1655 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9101 0.1623 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8228 0.1631 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8925 0.1639 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8460 0.1691 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8299 0.1600 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8848 0.1631 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8981 0.1626 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8818 0.1635 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8873 0.1625 sec/batch
# Nearest to all: grover, every, apocalypses, is, enables, they, punitive, finishing,
# Nearest to while: watered, appeasing, contagious, knocks, swing, hangovers, a, sponge,
# Nearest to would: mond, unsuccessfully, pesky, upwardly, democratization, motive, isaac, nation,
# Nearest to not: accomplice, clown, but, emphatic, adoption, paracompact, their, jarring,
# Nearest to new: york, bibles, seneca, james, interbellum, callow, packard, incorporated,
# Nearest to or: a, grammars, some, coprophagia, heterogeneous, illiniwek, often, unfavourably,
# Nearest to up: atgm, yell, needed, worn, their, descendants, bikini, credibility,
# Nearest to than: compared, more, capacities, denominated, less, kilo, shuffled, gull,
# Nearest to institute: biotechnology, association, sciences, iit, loyola, specialists, vocational, departments,
# Nearest to rise: bubi, apotheosis, tempering, impotent, extreme, caen, sortavala, kushan,
# Nearest to numerous: fitter, electromechanical, nilgiri, trypanosoma, meadow, reinvention, entirely, boast,
# Nearest to versions: rabba, newer, folks, silmarillion, etext, rocker, psk, snatch,
# Nearest to alternative: wysiwyg, nlm, yezhov, labeled, bartley, dearth, sarabande, caveats,
# Nearest to units: si, unit, planar, multipole, internally, together, keypad, abidjan,
# Nearest to mainly: linings, curbing, csrt, flautist, transliterator, ottokar, redox, dazzle,
# Nearest to recorded: whispering, iommi, philharmonic, recording, track, session, lz, album,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9558 0.1646 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.9206 0.1683 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8573 0.1602 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9003 0.1621 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8867 0.1736 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9247 0.1622 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8427 0.1591 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8619 0.1617 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.8860 0.1669 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9650 0.1661 sec/batch
# Nearest to all: grover, is, apocalypses, every, ruffini, rankin, enables, finishing,
# Nearest to while: appeasing, swing, watered, contagious, knocks, a, corporatocracy, hangovers,
# Nearest to would: mond, unsuccessfully, isaac, expectation, describing, motive, pesky, puritanism,
# Nearest to not: accomplice, emphatic, but, adoption, may, clown, jarring, paracompact,
# Nearest to new: york, bibles, seneca, james, butterfield, eight, packard, incorporated,
# Nearest to or: grammars, illiniwek, a, usage, multiples, some, da, heterogeneous,
# Nearest to up: atgm, yell, bikini, credibility, tosses, crediting, descendants, dart,
# Nearest to than: compared, capacities, more, denominated, less, verdun, kilo, sutton,
# Nearest to institute: biotechnology, association, sciences, specialists, iit, loyola, tompkins, kindergarten,
# Nearest to rise: bubi, apotheosis, extreme, tempering, impotent, caen, sortavala, mankiewicz,
# Nearest to numerous: fitter, electromechanical, nilgiri, trypanosoma, reinvention, expedite, boast, entirely,
# Nearest to versions: rabba, newer, folks, silmarillion, etext, psk, rocker, caml,
# Nearest to alternative: wysiwyg, nlm, yezhov, bartley, labeled, dearth, legendary, sarabande,
# Nearest to units: si, unit, planar, multipole, together, internally, rostock, abidjan,
# Nearest to mainly: curbing, linings, csrt, emigrants, transliterator, ottokar, flautist, proto,
# Nearest to recorded: philharmonic, iommi, recording, whispering, session, album, goodbye, grossing,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9209 0.1728 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.8673 0.1819 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9217 0.1675 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8619 0.1608 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.8346 0.1611 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9027 0.1610 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8755 0.1829 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9726 0.1821 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 3.9775 0.1706 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 3.9466 0.1714 sec/batch
# Nearest to all: grover, apocalypses, marino, rankin, auntie, crowfoot, is, thwarting,
# Nearest to while: swing, appeasing, contagious, radiguet, watered, a, mcclellan, contempt,
# Nearest to would: unsuccessfully, mond, pesky, abramovich, expectation, puritanism, nation, motive,
# Nearest to not: accomplice, but, adoption, knows, clown, authorize, emphatic, jarring,
# Nearest to new: york, bibles, seneca, james, callow, butterfield, packard, kibaki,
# Nearest to or: illiniwek, grammars, restful, unfavourably, shipper, speeding, umno, bellevue,
# Nearest to up: atgm, yell, descendants, credibility, crediting, bikini, their, tosses,
# Nearest to than: compared, denominated, capacities, less, verdun, more, sutton, kilo,
# Nearest to institute: biotechnology, association, iit, sciences, specialists, loyola, tompkins, kindergarten,
# Nearest to rise: bubi, apotheosis, extreme, mankiewicz, caen, tempering, sortavala, impotent,
# Nearest to numerous: fitter, nilgiri, electromechanical, trypanosoma, reinvention, hardcover, grupo, stuyvesant,
# Nearest to versions: rabba, newer, folks, silmarillion, etext, snatch, caml, rocker,
# Nearest to alternative: yezhov, wysiwyg, bartley, nlm, legendary, dearth, sarabande, labeled,
# Nearest to units: si, unit, planar, safin, internally, multipole, rostock, together,
# Nearest to mainly: linings, curbing, transliterator, proto, ottokar, csrt, flautist, emigrants,
# Nearest to recorded: philharmonic, recording, iommi, goodbye, track, session, album, whispering,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.8991 0.1794 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8711 0.1618 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.8638 0.1617 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.7566 0.1821 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.8876 0.1709 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.8924 0.1660 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.8831 0.1627 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9454 0.0432 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.8759 0.1616 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.8585 0.1628 sec/batch
# Nearest to all: grover, every, rankin, is, apocalypses, ruffini, auntie, crowfoot,
# Nearest to while: contagious, appeasing, a, mcclellan, swing, transnistria, knocks, watered,
# Nearest to would: mond, unsuccessfully, upwardly, expectation, motive, pesky, bakesperson, abramovich,
# Nearest to not: accomplice, adoption, but, knows, emphatic, does, may, codd,
# Nearest to new: york, bibles, seneca, butterfield, callow, packard, james, kibaki,
# Nearest to or: grammars, usage, unfavourably, some, illiniwek, shipper, often, bellevue,
# Nearest to up: atgm, yell, descendants, credibility, dart, tosses, their, crediting,
# Nearest to than: compared, denominated, sutton, capacities, more, less, verdun, oilfields,
# Nearest to institute: biotechnology, association, iit, specialists, loyola, kindergarten, sciences, departments,
# Nearest to rise: bubi, apotheosis, extreme, kushan, tempering, mankiewicz, caen, sortavala,
# Nearest to numerous: nilgiri, electromechanical, fitter, reinvention, boast, chevron, trypanosoma, deporting,
# Nearest to versions: rabba, newer, folks, snatch, etext, caml, silmarillion, masami,
# Nearest to alternative: wysiwyg, yezhov, nlm, sarabande, bartley, labeled, dearth, caveats,
# Nearest to units: si, unit, planar, multipole, rostock, safin, together, abidjan,
# Nearest to mainly: curbing, linings, ottokar, flautist, transliterator, context, csrt, proto,
# Nearest to recorded: recording, philharmonic, session, whispering, iommi, track, goodbye, album,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8698 0.1706 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.8767 0.1706 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8289 0.1709 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8587 0.1634 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8312 0.1660 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.8642 0.1638 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8787 0.1626 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9349 0.1697 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8332 0.1607 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.7863 0.1634 sec/batch
# Nearest to all: grover, every, rankin, with, marino, is, enables, they,
# Nearest to while: a, appeasing, outwit, swing, mcclellan, contagious, watered, turbulence,
# Nearest to would: unsuccessfully, mond, upwardly, fyrom, pesky, puritanism, motive, abramovich,
# Nearest to not: accomplice, adoption, but, their, multifinder, emphatic, paracompact, a,
# Nearest to new: york, bibles, seneca, james, interbellum, butterfield, qarase, incorporated,
# Nearest to or: grammars, a, usage, some, illiniwek, shipper, unfavourably, those,
# Nearest to up: atgm, yell, their, descendants, credibility, dart, bikini, saginaw,
# Nearest to than: compared, more, denominated, oilfields, less, capacities, sutton, gull,
# Nearest to institute: biotechnology, association, iit, specialists, kindergarten, sciences, loyola, vocational,
# Nearest to rise: bubi, apotheosis, extreme, caen, tempering, sortavala, kushan, bivouac,
# Nearest to numerous: electromechanical, fitter, nilgiri, trypanosoma, chevron, hardcover, masala, reinvention,
# Nearest to versions: rabba, newer, snatch, caml, folks, silmarillion, psk, etext,
# Nearest to alternative: nlm, wysiwyg, yezhov, bartley, labeled, sarabande, dearth, caveats,
# Nearest to units: unit, si, planar, five, safin, multipole, rostock, together,
# Nearest to mainly: curbing, linings, ottokar, flautist, csrt, esplanade, transliterator, this,
# Nearest to recorded: recording, session, philharmonic, whispering, iommi, track, lz, album,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8351 0.1670 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.7504 0.1667 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8410 0.1668 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.8635 0.1632 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8401 0.1709 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8097 0.1629 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9300 0.1672 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8342 0.1622 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8486 0.1626 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8488 0.1750 sec/batch
# Nearest to all: grover, every, is, are, enables, with, apocalypses, they,
# Nearest to while: a, swing, appeasing, knocks, mcclellan, outwit, contagious, turbulence,
# Nearest to would: unsuccessfully, mond, upwardly, bakesperson, motive, clerk, isaac, democratization,
# Nearest to not: accomplice, but, adoption, emphatic, paracompact, may, uncircumcised, able,
# Nearest to new: york, bibles, seneca, james, incorporated, suny, butterfield, eight,
# Nearest to or: a, usage, grammars, is, some, those, restful, often,
# Nearest to up: atgm, yell, tosses, dart, their, credibility, descendants, needed,
# Nearest to than: compared, capacities, more, denominated, sutton, less, shuffled, gull,
# Nearest to institute: biotechnology, association, loyola, sciences, iit, kindergarten, specialists, community,
# Nearest to rise: bubi, apotheosis, caen, kushan, sortavala, tempering, extreme, bivouac,
# Nearest to numerous: electromechanical, fitter, nilgiri, reinvention, trypanosoma, boast, hardcover, appear,
# Nearest to versions: rabba, newer, snatch, silmarillion, caml, etext, folks, masami,
# Nearest to alternative: nlm, wysiwyg, yezhov, labeled, caveats, bartley, sarabande, dearth,
# Nearest to units: si, unit, planar, together, five, rostock, safin, multipole,
# Nearest to mainly: curbing, linings, usage, context, transliterator, flautist, ottokar, csrt,
# Nearest to recorded: recording, session, philharmonic, whispering, iommi, goodbye, track, album,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8740 0.1804 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9019 0.1810 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8248 0.1643 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.8562 0.1628 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.9038 0.1617 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.8750 0.1611 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.8754 0.1615 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.8671 0.1606 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.8557 0.1697 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
