# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:14, 2.14MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
train_words = []
words_freqs = Counter(int_words)

def drop_prob(t, freq):
    return 1 - np.sqrt(t/freq)

for word in int_words:
    drop = drop_prob(1e-5, words_freqs[word]/len(int_words))
    if drop < random.random():
        train_words.append(word)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randrange(1, window_size+1)
    
    start_idx = idx - r if (idx - r) > 0 else 0
    stop_idx = idx + r
    
    window = words[start_idx:idx] + words[idx+1:stop_idx]
    
    return window

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    # create softmax biases here                        
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6119 0.0764 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5626 0.0688 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4495 0.0702 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5331 0.0715 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4686 0.0692 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4744 0.0714 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4929 0.0715 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4895 0.0714 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4103 0.0711 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3858 0.0710 sec/batch
# Nearest to american: deol, stargate, rocked, apologized, mosquitia, stwa, cueing, pathname,
# Nearest to these: tdi, milliardo, categorizations, twice, murakami, ribonucleic, heechee, names,
# Nearest to than: deduce, hco, shameless, baptize, scandinavians, dns, moments, regnal,
# Nearest to united: cavalryman, informative, cade, indiscernibles, autoimmunity, bechuanaland, doonesbury, myles,
# Nearest to four: judgements, defective, exoskeleton, earnings, pakistan, blossoms, chart, kiang,
# Nearest to had: treatises, psychologically, gpcrs, brash, atal, laundering, fandom, manifold,
# Nearest to been: duse, fascists, zimbardo, noodles, anaesthetic, bolus, divergent, totality,
# Nearest to th: frets, bloody, cyrene, shinai, leaps, correggio, negating, depression,
# Nearest to except: defect, conceivable, scrolling, paleo, mouch, marque, theta, reduces,
# Nearest to test: deckard, sender, hyi, merleau, transcribe, crossbows, fore, north,
# Nearest to http: appleseed, bosman, peru, damascus, conscious, praetors, cafeteria, elbert,
# Nearest to discovered: quantified, unsigned, introverted, postmillennial, som, reeling, bacharach, challenger,
# Nearest to something: trunks, sensual, multiprocessor, periphrastic, batoche, hafnium, evesham, assaults,
# Nearest to existence: mandeville, mic, hommes, liam, outrun, gpa, cheng, danson,
# Nearest to liberal: epithets, downed, radha, battuta, paternalistic, raaf, majapahit, suffixes,
# Nearest to issue: danced, megabats, wash, whetstone, broadened, starship, luc, storylines,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4564 0.0728 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3513 0.0712 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3493 0.0708 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2161 0.0721 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2274 0.0721 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2011 0.0719 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1162 0.0716 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1011 0.0704 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0402 0.0699 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0511 0.0722 sec/batch
# Nearest to american: stargate, mosquitia, apologized, kept, rocked, deol, lifts, doug,
# Nearest to these: twice, names, categorizations, collected, protagonist, tdi, milliardo, murakami,
# Nearest to than: deduce, hco, chose, severely, discs, west, do, advent,
# Nearest to united: country, cavalryman, substantial, informative, satisfy, dennis, canada, doonesbury,
# Nearest to four: defective, judgements, pakistan, towns, planning, duties, chart, blossoms,
# Nearest to had: treatises, psychologically, laundering, manifold, remained, directors, any, gpcrs,
# Nearest to been: for, duse, noodles, divergent, fascists, totality, another, learned,
# Nearest to th: frets, part, depression, bloody, kill, leaps, theoretically, excesses,
# Nearest to except: defect, scrolling, almost, conceivable, theta, reduces, einstein, gradual,
# Nearest to test: fore, crossbows, north, sender, vesalius, hyi, engineer, deckard,
# Nearest to http: appleseed, bosman, peru, player, damascus, conscious, praetors, elbert,
# Nearest to discovered: quantified, introverted, unsigned, labelled, non, postmillennial, challenger, soldiers,
# Nearest to something: trunks, vaccine, batoche, sensual, feudal, economics, harwood, supported,
# Nearest to existence: mandeville, relationships, liam, hbt, xof, mic, tchaikovsky, hommes,
# Nearest to liberal: epithets, raaf, downed, battuta, paternalistic, christmas, suffixes, african,
# Nearest to issue: megabats, danced, wash, architecture, broadened, starship, whetstone, storylines,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9697 0.0727 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9120 0.0718 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8610 0.0722 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9030 0.0731 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8139 0.0724 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8458 0.0724 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8072 0.0715 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7909 0.0700 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7959 0.0717 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7898 0.0725 sec/batch
# Nearest to american: stargate, apologized, mosquitia, rocked, doug, kept, lifts, deol,
# Nearest to these: names, twice, milliardo, collected, categorizations, masonic, protagonist, heretics,
# Nearest to than: deduce, hco, moments, discs, sponsored, severely, advent, user,
# Nearest to united: cavalryman, country, substantial, protective, informative, saddle, satisfy, benedict,
# Nearest to four: blossoms, judgements, chart, defective, earnings, five, pakistan, conflicts,
# Nearest to had: treatises, psychologically, manifold, laundering, fandom, scots, remained, gpcrs,
# Nearest to been: fascists, duse, noodles, for, divergent, totality, sadr, anaesthetic,
# Nearest to th: frets, bloody, part, excesses, ashkenazi, depression, cyrene, kill,
# Nearest to except: defect, reduces, gradual, almost, scrolling, einstein, theta, conceivable,
# Nearest to test: sender, fore, transformations, vesalius, north, engineer, wasn, transcribe,
# Nearest to http: bosman, appleseed, peru, conscious, player, whitmore, administrative, deducted,
# Nearest to discovered: quantified, unsigned, introverted, challenger, postmillennial, labelled, moreau, liberties,
# Nearest to something: trunks, supported, boycotted, vaccine, feudal, pbs, sensual, economics,
# Nearest to existence: mandeville, relationships, mic, soundtracks, liam, hommes, tchaikovsky, aqueous,
# Nearest to liberal: downed, epithets, raaf, christmas, african, political, suffixes, neptune,
# Nearest to issue: danced, megabats, broadened, afghanistan, architecture, storylines, phone, starship,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7934 0.0737 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7631 0.0725 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7400 0.0725 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7101 0.0718 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7362 0.0717 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7210 0.0722 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7148 0.0721 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7046 0.0724 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6878 0.0726 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6663 0.0719 sec/batch
# Nearest to american: doug, stargate, deol, apologized, mosquitia, lifts, rocked, zoological,
# Nearest to these: categorizations, names, milliardo, collected, taxonomy, therapies, ribonucleic, twice,
# Nearest to than: deduce, hco, moments, shameless, atrocious, user, discs, sponsored,
# Nearest to united: country, cavalryman, substantial, saddle, protective, benedict, elected, canada,
# Nearest to four: three, five, two, blossoms, eight, judgements, earnings, paved,
# Nearest to had: treatises, psychologically, remained, lithuania, manifold, zimbabwe, apprentice, scots,
# Nearest to been: duse, fascists, anaesthetic, divergent, sadr, for, totality, noodles,
# Nearest to th: frets, bloody, excesses, part, ashkenazi, defectors, patton, cyrene,
# Nearest to except: defect, reduces, scrolling, gradual, almost, conceivable, paleo, theta,
# Nearest to test: sender, transcribe, transformations, pickling, engineer, vesalius, portability, fore,
# Nearest to http: bosman, appleseed, peru, conscious, deducted, whitmore, player, lameness,
# Nearest to discovered: quantified, unsigned, introverted, challenger, postmillennial, reeling, bacharach, propositional,
# Nearest to something: trunks, boycotted, attainable, supported, pbs, sensual, fossils, csa,
# Nearest to existence: mandeville, mic, relationships, hommes, soundtracks, liam, tchaikovsky, gpa,
# Nearest to liberal: downed, epithets, political, raaf, christmas, suffixes, cabinet, african,
# Nearest to issue: danced, afghanistan, broadened, storylines, megabats, starship, phone, luc,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6653 0.0731 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6880 0.0718 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6296 0.0725 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6418 0.0723 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6356 0.0688 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6058 0.0708 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6161 0.0539 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5515 0.0714 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5122 0.0715 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5198 0.0713 sec/batch
# Nearest to american: doug, stargate, stephen, deol, nobel, politician, apologized, vocalist,
# Nearest to these: categorizations, therapies, names, milliardo, standardized, ribonucleic, collected, taxonomy,
# Nearest to than: deduce, hco, moments, discs, shameless, user, faa, multifinder,
# Nearest to united: country, cavalryman, saddle, canada, substantial, benedict, elected, deutscher,
# Nearest to four: five, three, two, blossoms, eight, theologian, seven, marmara,
# Nearest to had: psychologically, remained, treatises, apprentice, affiliations, lithuania, manifold, flowery,
# Nearest to been: duse, fascists, anaesthetic, zimbardo, totality, sadr, divergent, antonine,
# Nearest to th: frets, bloody, excesses, ashkenazi, part, specie, defectors, deux,
# Nearest to except: defect, scrolling, gradual, perusal, theta, almost, reduces, conceivable,
# Nearest to test: sender, transformations, transcribe, crossbows, vesalius, portability, pickling, fore,
# Nearest to http: appleseed, bosman, peru, html, deducted, whitmore, www, diskette,
# Nearest to discovered: quantified, unsigned, postmillennial, introverted, som, challenger, bacharach, reeling,
# Nearest to something: trunks, csa, attainable, supported, boycotted, pbs, hafnium, sensual,
# Nearest to existence: mandeville, mic, soundtracks, gpa, relationships, hommes, proposes, isabela,
# Nearest to liberal: political, downed, epithets, cabinet, raaf, paternalistic, suffixes, christmas,
# Nearest to issue: danced, afghanistan, storylines, broadened, megabats, eventually, luc, whetstone,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5109 0.0722 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4721 0.0707 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4605 0.0715 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5333 0.0718 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4971 0.0710 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4703 0.0709 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4393 0.0710 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4171 0.0714 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4344 0.0711 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3985 0.0715 sec/batch
# Nearest to american: doug, stargate, deol, apologized, stephen, rocked, mosquitia, cueing,
# Nearest to these: therapies, categorizations, names, milliardo, ribonucleic, standardized, shrub, taxonomy,
# Nearest to than: deduce, hco, discs, moments, baptize, multifinder, faa, polluting,
# Nearest to united: country, cavalryman, canada, elected, saddle, substantial, parliamentary, queensland,
# Nearest to four: five, three, two, blossoms, zero, eight, paved, marmara,
# Nearest to had: remained, apprentice, psychologically, treatises, affiliations, bipartisan, flowery, tenuous,
# Nearest to been: fascists, anaesthetic, duse, zimbardo, sadr, divergent, banda, antonine,
# Nearest to th: frets, bloody, part, ashkenazi, century, miquelon, deux, excesses,
# Nearest to except: scrolling, defect, marque, gradual, conceivable, paleo, millimetre, tall,
# Nearest to test: sender, transformations, transcribe, exploded, galveston, portability, invested, crossbows,
# Nearest to http: www, html, bosman, appleseed, htm, links, deducted, whitmore,
# Nearest to discovered: quantified, unsigned, postmillennial, som, introverted, bacharach, reeling, propositional,
# Nearest to something: trunks, csa, attainable, fossils, hafnium, pbs, backtracking, postcolonial,
# Nearest to existence: mandeville, mic, hommes, proposes, gpa, relationships, soundtracks, isabela,
# Nearest to liberal: political, downed, cabinet, epithets, raaf, party, paternalistic, bir,
# Nearest to issue: danced, afghanistan, broadened, storylines, eventually, petition, phone, megabats,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4226 0.0725 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4281 0.0715 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4340 0.0713 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4029 0.0704 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4091 0.0718 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4208 0.0717 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3811 0.0718 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3381 0.0704 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4046 0.0695 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3590 0.0705 sec/batch
# Nearest to american: doug, stephen, stargate, deol, apologized, cueing, mosquitia, elliott,
# Nearest to these: milliardo, names, therapies, standardized, categorizations, gounod, shrub, ribonucleic,
# Nearest to than: deduce, hco, discs, moments, baptize, multifinder, instantaneous, severely,
# Nearest to united: country, cavalryman, canada, ambassador, saddle, deutscher, dennis, elected,
# Nearest to four: three, five, two, eight, blossoms, zero, paved, earnings,
# Nearest to had: remained, apprentice, flowery, psychologically, tenuous, superintendent, bipartisan, treatises,
# Nearest to been: anaesthetic, fascists, sadr, zimbardo, duse, banda, for, inuktitut,
# Nearest to th: frets, bloody, ashkenazi, century, miquelon, partitioned, part, specie,
# Nearest to except: scrolling, defect, marque, conceivable, gradual, almost, millimetre, vlaams,
# Nearest to test: sender, transformations, portability, transcribe, navier, ddc, galveston, flows,
# Nearest to http: www, html, htm, links, bosman, appleseed, diskette, whitmore,
# Nearest to discovered: quantified, unsigned, som, bacharach, suggest, postmillennial, introverted, propositional,
# Nearest to something: csa, attainable, postcolonial, trunks, backtracking, atonal, fossils, hafnium,
# Nearest to existence: mandeville, mic, proposes, gpa, hommes, divine, relationships, imperative,
# Nearest to liberal: political, cabinet, downed, party, paternalistic, bir, epithets, democrats,
# Nearest to issue: danced, afghanistan, broadened, petition, eventually, overwhelm, phone, megabats,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3394 0.0722 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3431 0.0711 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3410 0.0716 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3399 0.0715 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3670 0.0712 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3606 0.0706 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3984 0.0708 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3854 0.0710 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3108 0.0715 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2965 0.0719 sec/batch
# Nearest to american: doug, apologized, stephen, cueing, deol, americans, mosquitia, rocked,
# Nearest to these: milliardo, standardized, names, gounod, therapies, categorizations, ribonucleic, mississippians,
# Nearest to than: deduce, hco, baptize, multifinder, discs, moments, atrocious, instantaneous,
# Nearest to united: country, cavalryman, substantial, canada, adherence, parliamentary, ambassador, deutscher,
# Nearest to four: three, two, five, eight, zero, blossoms, earnings, seven,
# Nearest to had: remained, apprentice, scots, came, flowery, affiliations, coffers, superintendent,
# Nearest to been: anaesthetic, sadr, for, duse, fascists, zimbardo, roebuck, jobs,
# Nearest to th: century, frets, partitioned, bloody, miquelon, part, specie, besieged,
# Nearest to except: marque, defect, almost, scrolling, vlaams, gradual, paleo, millimetre,
# Nearest to test: sender, transformations, portability, navier, galveston, phy, transcribe, carcinogen,
# Nearest to http: www, htm, html, links, appleseed, bosman, diskette, whitmore,
# Nearest to discovered: quantified, unsigned, som, bacharach, postmillennial, suggest, propositional, abramson,
# Nearest to something: attainable, csa, postcolonial, backtracking, hafnium, sensual, trunks, scythe,
# Nearest to existence: mandeville, theological, divine, mic, gpa, proposes, hommes, isabela,
# Nearest to liberal: political, cabinet, incumbent, democrat, downed, democrats, bir, party,
# Nearest to issue: danced, afghanistan, petition, broadened, correlating, centrally, overwhelm, phone,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3482 0.0710 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2852 0.0701 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3707 0.0719 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3727 0.0696 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3707 0.0705 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2948 0.0713 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2851 0.0718 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3324 0.0718 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2195 0.0703 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3000 0.0716 sec/batch
# Nearest to american: doug, stephen, americans, deol, orientalist, elliott, apologized, cueing,
# Nearest to these: standardized, therapies, milliardo, gounod, mississippians, names, categorizations, ribonucleic,
# Nearest to than: deduce, hco, west, multifinder, baptize, polluting, discs, instantaneous,
# Nearest to united: cavalryman, country, substantial, canada, dennis, queensland, trinidad, parkman,
# Nearest to four: three, two, five, zero, eight, six, seven, blossoms,
# Nearest to had: remained, apprentice, came, psychologically, displacing, dockyard, flowery, soldiers,
# Nearest to been: zimbardo, jobs, anaesthetic, duse, fascists, banda, roebuck, sadr,
# Nearest to th: century, frets, partitioned, bloody, miquelon, mayotte, part, specie,
# Nearest to except: marque, scrolling, vlaams, defect, almost, gradual, majorities, paleo,
# Nearest to test: sender, phy, galveston, navier, transformations, suns, dowager, engineer,
# Nearest to http: www, htm, html, links, appleseed, diskette, bosman, deducted,
# Nearest to discovered: som, quantified, unsigned, bacharach, postmillennial, suggest, hermits, abramson,
# Nearest to something: backtracking, postcolonial, csa, attainable, hafnium, fleshed, sensual, atonal,
# Nearest to existence: theological, divine, proposes, mic, gpa, mandeville, hommes, isabela,
# Nearest to liberal: political, democrat, incumbent, cabinet, opposition, democrats, downed, majapahit,
# Nearest to issue: afghanistan, danced, petition, lizzie, correlating, centrally, geniuses, overwhelm,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3052 0.0730 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2855 0.0713 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3346 0.0346 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2482 0.0706 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1995 0.0711 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2077 0.0722 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2048 0.0716 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2044 0.0715 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1941 0.0712 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1439 0.0711 sec/batch
# Nearest to american: doug, orientalist, americans, cueing, deol, mosquitia, shaun, elliott,
# Nearest to these: milliardo, therapies, standardized, gounod, mississippians, names, laplacian, shrub,
# Nearest to than: deduce, hco, multifinder, west, discs, vapours, instantaneous, severely,
# Nearest to united: cavalryman, country, substantial, canada, dennis, concentrated, queensland, parkman,
# Nearest to four: three, five, two, zero, eight, six, seven, blossoms,
# Nearest to had: apprentice, remained, superintendent, came, soldiers, displacing, kidnapped, dockyard,
# Nearest to been: zimbardo, anaesthetic, for, banda, jobs, duse, roebuck, fascists,
# Nearest to th: century, partitioned, frets, part, mayotte, bloody, miquelon, specie,
# Nearest to except: scrolling, marque, vlaams, millimetre, defect, almost, paleo, mouch,
# Nearest to test: navier, phy, sender, galveston, suns, exploded, busting, portability,
# Nearest to http: www, htm, html, links, appleseed, diskette, bosman, whitmore,
# Nearest to discovered: som, unsigned, quantified, bacharach, postmillennial, suggest, quadrants, co,
# Nearest to something: backtracking, postcolonial, csa, attainable, hafnium, atonal, fleshed, theistic,
# Nearest to existence: theological, proposes, divine, mandeville, gpa, hommes, gnostic, views,
# Nearest to liberal: political, democrat, incumbent, cabinet, opposition, democrats, majapahit, raaf,
# Nearest to issue: danced, afghanistan, petition, lizzie, correlating, overwhelm, centrally, broadened,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2188 0.0722 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1599 0.0707 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2029 0.0717 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1246 0.0725 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1534 0.0726 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1307 0.0713 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1474 0.0724 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1598 0.0728 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1737 0.0727 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1485 0.0718 sec/batch
# Nearest to american: americans, doug, cueing, deol, mosquitia, orientalist, apologized, elliott,
# Nearest to these: therapies, standardized, milliardo, names, gounod, mississippians, laplacian, convoluted,
# Nearest to than: deduce, hco, multifinder, west, discs, instantaneous, fossiles, feed,
# Nearest to united: cavalryman, country, substantial, canada, queensland, trinidad, adherence, dennis,
# Nearest to four: three, two, five, zero, eight, six, seven, one,
# Nearest to had: remained, came, apprentice, superintendent, displacing, fandom, soldiers, bengal,
# Nearest to been: anaesthetic, zimbardo, for, duse, glottis, banda, jobs, roebuck,
# Nearest to th: century, frets, partitioned, afc, mayotte, part, miquelon, nfl,
# Nearest to except: vlaams, marque, scrolling, defect, millimetre, majorities, almost, open,
# Nearest to test: phy, sender, navier, galveston, typhoons, suns, portability, transformations,
# Nearest to http: www, htm, html, links, appleseed, whitmore, diskette, bosman,
# Nearest to discovered: som, unsigned, quantified, co, bacharach, suggest, postmillennial, abramson,
# Nearest to something: backtracking, csa, postcolonial, attainable, fleshed, theistic, sensual, hafnium,
# Nearest to existence: theological, proposes, divine, mandeville, gpa, gnostic, afflicted, hommes,
# Nearest to liberal: political, democrat, incumbent, bir, cabinet, democrats, party, opposition,
# Nearest to issue: lizzie, danced, petition, correlating, afghanistan, overwhelm, broadened, phone,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1401 0.0717 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1999 0.0706 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1528 0.0717 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1411 0.0721 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1367 0.0724 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1481 0.0723 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1519 0.0720 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1124 0.0720 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0936 0.0720 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1395 0.0719 sec/batch
# Nearest to american: doug, americans, orientalist, deol, cueing, mosquitia, shaun, elliott,
# Nearest to these: mississippians, milliardo, gounod, standardized, names, therapies, backlot, laplacian,
# Nearest to than: deduce, hco, multifinder, west, fossiles, overlaid, instantaneous, baptize,
# Nearest to united: cavalryman, country, substantial, canada, trinidad, parkman, concentrated, civil,
# Nearest to four: three, two, five, zero, eight, six, seven, one,
# Nearest to had: remained, came, superintendent, apprentice, displacing, fandom, later, maldivian,
# Nearest to been: zimbardo, anaesthetic, jobs, for, duse, banda, burke, fascists,
# Nearest to th: century, partitioned, frets, afc, nfl, mayotte, miquelon, kessinger,
# Nearest to except: marque, vlaams, scrolling, majorities, open, almost, defect, millimetre,
# Nearest to test: sender, navier, phy, portability, carcinogen, galveston, transformations, typhoons,
# Nearest to http: www, htm, html, links, appleseed, edu, com, whitmore,
# Nearest to discovered: som, unsigned, co, quantified, bacharach, abramson, suggest, postmillennial,
# Nearest to something: backtracking, csa, attainable, postcolonial, fleshed, hafnium, theistic, sensual,
# Nearest to existence: theological, proposes, divine, gpa, zhukov, hommes, mandeville, gnostic,
# Nearest to liberal: political, democrat, democrats, incumbent, bir, cabinet, opposition, party,
# Nearest to issue: petition, lizzie, danced, correlating, afghanistan, overwhelm, geniuses, phone,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1881 0.0736 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1459 0.0715 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1508 0.0727 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1559 0.0723 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1162 0.0723 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0974 0.0714 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1383 0.0728 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0931 0.0724 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1724 0.0727 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1908 0.0718 sec/batch
# Nearest to american: doug, americans, deol, orientalist, mosquitia, cueing, apologized, shaun,
# Nearest to these: standardized, mississippians, names, milliardo, gounod, backlot, iditarod, laplacian,
# Nearest to than: multifinder, deduce, west, hco, baptize, ippon, fossiles, overlaid,
# Nearest to united: cavalryman, substantial, canada, parkman, country, trinidad, civil, concentrated,
# Nearest to four: three, two, five, eight, zero, six, seven, one,
# Nearest to had: superintendent, remained, came, apprentice, displacing, later, were, fandom,
# Nearest to been: zimbardo, for, jobs, duse, banda, anaesthetic, roebuck, sadr,
# Nearest to th: century, partitioned, afc, frets, illyrian, mayotte, nfl, of,
# Nearest to except: vlaams, marque, scrolling, majorities, almost, open, perusal, displaying,
# Nearest to test: sender, navier, phy, carcinogen, galveston, transformations, portability, typhoons,
# Nearest to http: www, htm, html, appleseed, links, edu, whitmore, com,
# Nearest to discovered: som, co, unsigned, bacharach, abramson, wanda, postmillennial, sara,
# Nearest to something: backtracking, csa, postcolonial, fleshed, thinks, assaults, theistic, attainable,
# Nearest to existence: theological, emancipation, proposes, zhukov, positivism, hommes, divine, gnostic,
# Nearest to liberal: democrat, political, incumbent, democrats, bir, opposition, raaf, cabinet,
# Nearest to issue: petition, afghanistan, correlating, lizzie, danced, overwhelm, centrally, geniuses,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1922 0.0731 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1148 0.0685 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0824 0.0718 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1029 0.0721 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0146 0.0715 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1263 0.0714 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1144 0.0714 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1056 0.0695 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1957 0.0164 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1118 0.0719 sec/batch
# Nearest to american: americans, doug, orientalist, deol, mosquitia, cueing, apologized, laureate,
# Nearest to these: standardized, milliardo, backlot, names, mississippians, laplacian, therapies, gounod,
# Nearest to than: hco, multifinder, deduce, west, vapours, convenience, instantaneous, overlaid,
# Nearest to united: substantial, cavalryman, country, canada, trinidad, civil, parkman, concentrated,
# Nearest to four: three, two, five, zero, eight, seven, six, one,
# Nearest to had: came, remained, superintendent, later, displacing, apprentice, fandom, bengal,
# Nearest to been: zimbardo, for, banda, jobs, duse, anaesthetic, missourians, inuktitut,
# Nearest to th: century, partitioned, mayotte, afc, frets, illyrian, rd, nfl,
# Nearest to except: scrolling, vlaams, marque, open, almost, displaying, perusal, millimetre,
# Nearest to test: phy, galveston, navier, sender, carcinogen, typhoons, duff, childrearing,
# Nearest to http: www, htm, html, edu, appleseed, links, geocities, com,
# Nearest to discovered: som, unsigned, co, bacharach, abramson, suggest, quantified, postmillennial,
# Nearest to something: backtracking, postcolonial, csa, fleshed, attainable, thinks, atonal, theistic,
# Nearest to existence: theological, proposes, zhukov, emancipation, positivism, hommes, gnostic, divine,
# Nearest to liberal: democrat, political, democrats, incumbent, cabinet, raaf, opposition, majapahit,
# Nearest to issue: lizzie, petition, correlating, afghanistan, danced, overwhelm, centrally, phone,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0422 0.0725 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0595 0.0709 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0539 0.0714 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0018 0.0706 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0459 0.0709 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9911 0.0717 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0617 0.0716 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0602 0.0712 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1026 0.0713 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9874 0.0722 sec/batch
# Nearest to american: americans, mosquitia, orientalist, doug, deol, cueing, apologized, rocked,
# Nearest to these: standardized, milliardo, mississippians, laplacian, convoluted, names, therapies, gounod,
# Nearest to than: hco, multifinder, west, deduce, vapours, convenience, seventy, instantaneous,
# Nearest to united: substantial, cavalryman, canada, country, civil, queensland, concentrated, parkman,
# Nearest to four: three, five, two, zero, eight, seven, six, one,
# Nearest to had: came, remained, superintendent, displacing, later, apprentice, bengal, were,
# Nearest to been: zimbardo, for, anaesthetic, came, banda, inuktitut, secretarial, jobs,
# Nearest to th: century, afc, rd, partitioned, frets, nfl, illyrian, mayotte,
# Nearest to except: vlaams, scrolling, almost, marque, open, fiber, displaying, millimetre,
# Nearest to test: galveston, phy, navier, carcinogen, sender, duff, childrearing, kumba,
# Nearest to http: www, htm, html, edu, appleseed, geocities, links, com,
# Nearest to discovered: som, co, unsigned, abramson, suggest, bacharach, postmillennial, magnetism,
# Nearest to something: backtracking, fleshed, csa, postcolonial, attainable, ariadne, thinks, assaults,
# Nearest to existence: theological, positivism, zhukov, proposes, hommes, emancipation, fornax, bbwaa,
# Nearest to liberal: democrat, political, democrats, incumbent, opposition, cabinet, raaf, bova,
# Nearest to issue: lizzie, correlating, petition, overwhelm, danced, afghanistan, phone, methuen,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9872 0.0731 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0005 0.0711 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9840 0.0719 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0430 0.0717 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0477 0.0715 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0375 0.0714 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0207 0.0714 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0433 0.0712 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9972 0.0717 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0063 0.0716 sec/batch
# Nearest to american: americans, orientalist, deol, mosquitia, doug, cueing, laureate, shaun,
# Nearest to these: milliardo, standardized, mississippians, gounod, therapies, chlamydia, convoluted, approximates,
# Nearest to than: hco, deduce, multifinder, prefixing, convenience, west, instantaneous, bounce,
# Nearest to united: substantial, cavalryman, canada, testify, queensland, parkman, civil, russcol,
# Nearest to four: three, two, five, zero, eight, six, seven, one,
# Nearest to had: came, remained, superintendent, later, displacing, dischord, locked, apprentice,
# Nearest to been: zimbardo, for, anaesthetic, banda, came, sadr, inuktitut, duse,
# Nearest to th: century, afc, rd, nfl, frets, partitioned, mayotte, kessinger,
# Nearest to except: vlaams, scrolling, almost, open, marque, displaying, fiber, majorities,
# Nearest to test: carcinogen, phy, navier, sender, galveston, portability, transcribe, intelligence,
# Nearest to http: www, htm, html, edu, geocities, appleseed, shtml, links,
# Nearest to discovered: som, co, abramson, magnetism, unsigned, suggest, quantified, bacharach,
# Nearest to something: backtracking, fleshed, csa, attainable, thinks, postcolonial, theistic, hafnium,
# Nearest to existence: theological, proposes, positivism, emancipation, hommes, fornax, zhukov, bbwaa,
# Nearest to liberal: democrat, political, democrats, incumbent, opposition, cabinet, bova, party,
# Nearest to issue: lizzie, correlating, afghanistan, methuen, danced, petition, overwhelm, maximally,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0005 0.0729 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0374 0.0721 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0499 0.0724 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9806 0.0716 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0309 0.0708 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0291 0.0708 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0221 0.0713 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0277 0.0706 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0502 0.0708 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0243 0.0722 sec/batch
# Nearest to american: americans, deol, mosquitia, orientalist, doug, cueing, lep, politician,
# Nearest to these: standardized, milliardo, mississippians, gounod, laplacian, approximates, grander, backlot,
# Nearest to than: deduce, multifinder, hco, west, prefixing, elysium, seventy, overlaid,
# Nearest to united: substantial, cavalryman, canada, testify, civil, country, trinidad, states,
# Nearest to four: three, two, zero, five, eight, six, seven, one,
# Nearest to had: remained, came, later, superintendent, displacing, were, soldiery, bengal,
# Nearest to been: zimbardo, banda, anaesthetic, sadr, for, duse, missourians, mamet,
# Nearest to th: century, rd, afc, partitioned, frets, illyrian, nfl, pozsony,
# Nearest to except: vlaams, almost, displaying, open, scrolling, marque, majorities, sihanoukville,
# Nearest to test: phy, sender, carcinogen, galveston, navier, intelligence, childrearing, duff,
# Nearest to http: www, htm, html, edu, shtml, geocities, appleseed, org,
# Nearest to discovered: som, co, abramson, magnetism, discovery, unsigned, bacharach, suggest,
# Nearest to something: backtracking, fleshed, csa, attainable, assaults, oath, thinks, ariadne,
# Nearest to existence: theological, proposes, positivism, emancipation, fornax, hommes, bbwaa, zhukov,
# Nearest to liberal: democrat, democrats, political, incumbent, opposition, cabinet, raaf, downed,
# Nearest to issue: correlating, lizzie, afghanistan, petition, methuen, overwhelm, centrally, phone,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0262 0.0724 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9787 0.0694 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9780 0.0716 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0312 0.0722 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0610 0.0699 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1053 0.0707 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0931 0.0712 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0066 0.0721 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9682 0.0717 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0285 0.0710 sec/batch
# Nearest to american: americans, deol, orientalist, doug, mosquitia, cueing, neale, politician,
# Nearest to these: standardized, milliardo, approximates, backlot, gounod, laplacian, chlamydia, mississippians,
# Nearest to than: multifinder, hco, deduce, seventy, west, prefixing, convenience, lauter,
# Nearest to united: substantial, cavalryman, testify, states, nations, civil, canada, russcol,
# Nearest to four: three, two, zero, eight, five, six, seven, one,
# Nearest to had: came, remained, later, superintendent, displacing, soldiery, bengal, wife,
# Nearest to been: zimbardo, banda, anaesthetic, inuktitut, astrometry, sadr, sessile, for,
# Nearest to th: century, afc, rd, frets, nfl, partitioned, kessinger, illyrian,
# Nearest to except: vlaams, almost, displaying, scrolling, open, marque, sihanoukville, unionized,
# Nearest to test: phy, carcinogen, sender, navier, galveston, intelligence, childrearing, duff,
# Nearest to http: www, htm, html, edu, geocities, shtml, appleseed, org,
# Nearest to discovered: som, co, abramson, magnetism, unsigned, suggest, discovery, eruption,
# Nearest to something: backtracking, fleshed, attainable, csa, thinks, hafnium, assaults, ariadne,
# Nearest to existence: theological, emancipation, hommes, bbwaa, zhukov, fornax, proposes, positivism,
# Nearest to liberal: democrat, democrats, political, incumbent, opposition, party, bova, social,
# Nearest to issue: correlating, lizzie, afghanistan, methuen, petition, maximally, overwhelm, centrally,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9386 0.0723 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0162 0.0708 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9979 0.0717 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9876 0.0714 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0732 0.0717 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0009 0.0692 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9762 0.0722 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9536 0.0721 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9792 0.0712 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9477 0.0712 sec/batch
# Nearest to american: americans, deol, orientalist, doug, cueing, mosquitia, politician, neale,
# Nearest to these: standardized, approximates, milliardo, chlamydia, convoluted, backlot, laplacian, gounod,
# Nearest to than: hco, multifinder, deduce, seventy, elysium, fossiles, vacancies, west,
# Nearest to united: substantial, cavalryman, states, testify, russcol, canada, nations, kashima,
# Nearest to four: three, two, five, zero, eight, six, seven, one,
# Nearest to had: came, later, remained, displacing, superintendent, soldiery, were, locked,
# Nearest to been: zimbardo, banda, anaesthetic, inuktitut, came, posten, astrometry, sessile,
# Nearest to th: century, afc, rd, nfl, kessinger, frets, pozsony, mayotte,
# Nearest to except: vlaams, scrolling, displaying, open, marque, almost, sihanoukville, mutiny,
# Nearest to test: phy, galveston, carcinogen, navier, duff, typhoons, dowager, sender,
# Nearest to http: www, htm, html, geocities, edu, shtml, appleseed, org,
# Nearest to discovered: som, discovery, magnetism, eruption, abramson, co, suggest, bacharach,
# Nearest to something: backtracking, fleshed, csa, oath, attainable, ariadne, thinks, assaults,
# Nearest to existence: theological, emancipation, positivism, fornax, proposes, cartesian, bbwaa, hommes,
# Nearest to liberal: democrat, democrats, political, incumbent, opposition, bova, downed, raaf,
# Nearest to issue: lizzie, correlating, maximally, afghanistan, methuen, overwhelm, petition, phone,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9582 0.0725 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8946 0.0721 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9803 0.0718 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0092 0.0717 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9513 0.0717 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9528 0.0713 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8630 0.0716 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9040 0.0722 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8868 0.0720 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9530 0.0715 sec/batch
# Nearest to american: americans, deol, cueing, mosquitia, orientalist, doug, islander, politician,
# Nearest to these: standardized, laplacian, milliardo, the, grander, convoluted, gounod, backstage,
# Nearest to than: hco, multifinder, seventy, deduce, it, fossiles, bounce, bungalow,
# Nearest to united: substantial, states, canada, cavalryman, kashima, russcol, nations, testify,
# Nearest to four: three, two, five, zero, eight, six, seven, one,
# Nearest to had: came, remained, later, displacing, soldiery, superintendent, were, dischord,
# Nearest to been: zimbardo, banda, anaesthetic, inuktitut, came, astrometry, sadr, controversy,
# Nearest to th: century, afc, rd, nfl, frets, kessinger, early, illyrian,
# Nearest to except: vlaams, displaying, scrolling, open, almost, marque, fiber, unionized,
# Nearest to test: phy, galveston, carcinogen, navier, duff, typhoons, dowager, sender,
# Nearest to http: www, htm, html, geocities, edu, shtml, appleseed, org,
# Nearest to discovered: som, discovery, magnetism, co, abramson, eruption, planetary, suggest,
# Nearest to something: backtracking, fleshed, csa, oath, thinks, attainable, ariadne, assaults,
# Nearest to existence: proposes, fornax, cartesian, emancipation, positivism, theological, hommes, zhukov,
# Nearest to liberal: democrat, democrats, political, incumbent, opposition, bova, party, parties,
# Nearest to issue: correlating, lizzie, methuen, afghanistan, petition, maximally, overwhelm, centrally,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9478 0.0725 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9579 0.0715 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9710 0.0713 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9720 0.0718 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9755 0.0714 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8962 0.0711 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9624 0.0715 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9474 0.0712 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9572 0.0713 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9434 0.0707 sec/batch
# Nearest to american: americans, deol, orientalist, politician, doug, mosquitia, laureate, wrestler,
# Nearest to these: standardized, milliardo, grander, convoluted, chlamydia, gounod, laplacian, backlot,
# Nearest to than: hco, multifinder, seventy, deduce, fossiles, prefixing, elysium, speedy,
# Nearest to united: substantial, states, russcol, kashima, cavalryman, canada, testify, parkman,
# Nearest to four: three, two, eight, zero, five, six, seven, one,
# Nearest to had: came, remained, later, superintendent, soldiery, were, displacing, began,
# Nearest to been: zimbardo, banda, came, astrometry, sadr, inuktitut, controversy, mamet,
# Nearest to th: century, rd, afc, nfl, kessinger, pozsony, frets, early,
# Nearest to except: vlaams, displaying, open, scrolling, almost, marque, mutiny, unionized,
# Nearest to test: phy, carcinogen, navier, galveston, dowager, sender, intelligence, duff,
# Nearest to http: www, htm, html, geocities, edu, shtml, appleseed, org,
# Nearest to discovered: som, discovery, magnetism, abramson, co, eruption, planetary, suggest,
# Nearest to something: backtracking, fleshed, csa, thinks, oath, theistic, ariadne, das,
# Nearest to existence: fornax, positivism, emancipation, proposes, cartesian, hommes, theological, bbwaa,
# Nearest to liberal: democrat, democrats, political, incumbent, opposition, bova, conservative, parties,
# Nearest to issue: lizzie, correlating, methuen, afghanistan, petition, overwhelm, centrally, phone,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9616 0.0699 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9455 0.0709 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9374 0.0715 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9547 0.0715 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9727 0.0717 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9310 0.0713 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9440 0.0719 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9391 0.0710 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9323 0.0698 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9845 0.0720 sec/batch
# Nearest to american: americans, deol, politician, orientalist, doug, neale, mosquitia, athlete,
# Nearest to these: standardized, milliardo, are, laplacian, grander, approximates, chlamydia, convoluted,
# Nearest to than: multifinder, seventy, hco, rising, asa, convenience, fossiles, prefixing,
# Nearest to united: states, substantial, canada, nations, kashima, cavalryman, presidents, russcol,
# Nearest to four: three, two, five, eight, zero, six, seven, one,
# Nearest to had: came, remained, later, soldiery, began, were, displacing, superintendent,
# Nearest to been: zimbardo, banda, inuktitut, controversy, anaesthetic, astrometry, came, for,
# Nearest to th: century, rd, afc, nfl, kessinger, early, pozsony, partitioned,
# Nearest to except: vlaams, displaying, open, scrolling, mutiny, almost, marque, unionized,
# Nearest to test: phy, carcinogen, galveston, navier, intelligence, dowager, childrearing, sender,
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8275 0.0696 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8668 0.0702 sec/batch
# Nearest to american: americans, deol, brooklynites, entoprocta, wrestler, mrc, orientalist, hispanic,
# Nearest to these: are, known, as, the, other, standardized, to, oboe,
# Nearest to than: more, seventy, less, hco, it, expending, make, widely,
# Nearest to united: states, nations, testify, canada, is, of, preamble, western,
# Nearest to four: two, three, one, five, six, zero, eight, seven,
# Nearest to had: later, came, were, could, remained, already, became, lasted,
# Nearest to been: have, since, has, though, came, lookups, astrometry, was,
# Nearest to th: century, rd, nfl, early, rematch, late, afc, this,
# Nearest to except: vlaams, forms, displaying, mercy, kaunda, dominion, plucking, interchangeable,
# Nearest to test: matches, cricinfo, cricket, galveston, phy, distributions, tests, carcinogen,
# Nearest to http: www, htm, html, shtml, geocities, edu, org, com,
# Nearest to discovered: discovery, som, jupiter, mariners, eruption, planetary, proxies, abramson,
# Nearest to something: backtracking, oath, das, get, does, fleshed, csa, thinks,
# Nearest to existence: fornax, watcher, smarta, emancipation, cops, clifton, liam, triumphant,
# Nearest to liberal: democrats, democrat, incumbent, class, conservative, starve, alde, political,
# Nearest to issue: comics, correlating, methuen, lizzie, behaves, commissioner, vastly, multiplexer,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7630 0.0703 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7829 0.0679 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7922 0.0697 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8144 0.0714 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7890 0.0701 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8121 0.0702 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7864 0.0689 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7815 0.0699 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8039 0.0711 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8346 0.0721 sec/batch
# Nearest to american: americans, deol, brooklynites, entoprocta, mrc, wrestler, agnew, hispanic,
# Nearest to these: are, known, as, other, in, the, standardized, oboe,
# Nearest to than: more, seventy, much, eight, in, it, widely, less,
# Nearest to united: states, nations, testify, warship, an, canada, is, of,
# Nearest to four: two, three, five, zero, one, six, eight, seven,
# Nearest to had: later, came, remained, were, already, lasted, became, could,
# Nearest to been: have, since, though, has, was, came, already, researchers,
# Nearest to th: century, rd, early, this, late, nfl, according, rematch,
# Nearest to except: vlaams, forms, displaying, mercy, interchangeable, kaunda, almost, sihanoukville,
# Nearest to test: matches, cricinfo, galveston, cricket, tests, phy, distributions, childrearing,
# Nearest to http: www, htm, html, shtml, geocities, edu, org, appleseed,
# Nearest to discovered: discovery, som, jupiter, mariners, eruption, proxies, planetary, elcano,
# Nearest to something: oath, get, backtracking, das, csa, does, misspelling, thinks,
# Nearest to existence: fornax, watcher, smarta, not, emancipation, triumphant, villain, liam,
# Nearest to liberal: democrats, democrat, incumbent, class, conservative, starve, alde, political,
# Nearest to issue: comics, lizzie, correlating, methuen, commissioner, vastly, eurosceptics, frontman,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7839 0.0722 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7847 0.0716 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7748 0.0710 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7834 0.0712 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8510 0.0711 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7994 0.0713 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9059 0.0707 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8258 0.0714 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8290 0.0712 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7526 0.0709 sec/batch
# Nearest to american: americans, deol, brooklynites, entoprocta, hispanic, mrc, wrestler, agnew,
# Nearest to these: are, known, standardized, as, the, other, flagging, oboe,
# Nearest to than: more, eight, seventy, it, although, much, widely, however,
# Nearest to united: states, nations, testify, is, warship, notably, canada, cvn,
# Nearest to four: two, three, one, zero, six, five, eight, nine,
# Nearest to had: later, came, became, remained, were, was, could, began,
# Nearest to been: have, has, since, though, was, came, for, leaked,
# Nearest to th: century, rd, early, late, this, rematch, nfl, afc,
# Nearest to except: vlaams, forms, kaunda, mercy, almost, sihanoukville, flooded, displaying,
# Nearest to test: matches, cricinfo, galveston, tests, cricket, distributions, phy, mathcal,
# Nearest to http: www, htm, html, shtml, geocities, edu, org, appleseed,
# Nearest to discovered: discovery, som, jupiter, mariners, proxies, eruption, been, elcano,
# Nearest to something: oath, get, does, backtracking, thinks, misspelling, joanie, csa,
# Nearest to existence: fornax, emancipation, watcher, triumphant, vald, smarta, villain, transylvania,
# Nearest to liberal: democrats, democrat, incumbent, class, conservative, alde, progressive, starve,
# Nearest to issue: comics, correlating, methuen, lizzie, commissioner, vastly, frontman, king,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7299 0.0727 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7899 0.0715 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7506 0.0715 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8199 0.0719 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7765 0.0704 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7662 0.0707 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8176 0.0478 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7917 0.0714 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7530 0.0711 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7948 0.0712 sec/batch
# Nearest to american: americans, deol, brooklynites, entoprocta, hispanic, mrc, estrada, laird,
# Nearest to these: are, known, as, other, the, standardized, oboe, in,
# Nearest to than: more, much, it, have, widely, although, less, seventy,
# Nearest to united: states, nations, is, testify, warship, canada, cvn, western,
# Nearest to four: two, three, one, six, five, zero, eight, nine,
# Nearest to had: later, came, could, were, already, became, was, remained,
# Nearest to been: have, has, since, though, was, came, for, as,
# Nearest to th: century, rd, this, early, late, nfl, rematch, today,
# Nearest to except: vlaams, forms, mercy, kaunda, flooded, interchangeable, sihanoukville, baggins,
# Nearest to test: matches, cricinfo, tests, cricket, galveston, cricketing, mathcal, distributions,
# Nearest to http: www, htm, html, shtml, geocities, edu, org, appleseed,
# Nearest to discovered: discovery, jupiter, som, mariners, later, been, eruption, was,
# Nearest to something: backtracking, oath, get, does, misspelling, joanie, das, csa,
# Nearest to existence: not, fornax, watcher, emancipation, triumphant, smarta, vald, transylvania,
# Nearest to liberal: democrats, democrat, incumbent, class, conservative, starve, affiliated, downed,
# Nearest to issue: correlating, comics, methuen, lizzie, vastly, eurosceptics, recognized, commissioner,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7501 0.0715 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7656 0.0710 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7509 0.0712 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7757 0.0713 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8102 0.0714 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7914 0.0700 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8229 0.0706 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6910 0.0723 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7591 0.0704 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7156 0.0715 sec/batch
# Nearest to american: americans, entoprocta, deol, brooklynites, hispanic, mrc, cueing, mosquitia,
# Nearest to these: are, known, the, other, as, in, standardized, to,
# Nearest to than: more, it, less, although, have, in, widely, much,
# Nearest to united: states, nations, canada, warship, testify, notably, western, cvn,
# Nearest to four: three, two, one, six, zero, five, eight, seven,
# Nearest to had: later, could, came, already, were, became, remained, was,
# Nearest to been: have, has, since, though, was, researchers, known, but,
# Nearest to th: century, rd, early, late, this, nfl, today, afc,
# Nearest to except: vlaams, forms, mercy, sihanoukville, almost, displaying, flooded, plucking,
# Nearest to test: matches, cricinfo, tests, cricket, galveston, cricketing, phy, mathcal,
# Nearest to http: www, htm, html, shtml, geocities, edu, org, appleseed,
# Nearest to discovered: discovery, jupiter, som, been, eruption, proxies, mariners, had,
# Nearest to something: backtracking, oath, get, misspelling, joanie, does, csa, das,
# Nearest to existence: fornax, watcher, vald, liam, clifton, not, triumphant, transylvania,
# Nearest to liberal: democrats, democrat, incumbent, conservative, class, nr, starve, progressive,
# Nearest to issue: correlating, comics, lizzie, methuen, vastly, recognized, gibi, commissioner,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6901 0.0722 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7473 0.0711 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8108 0.0710 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7296 0.0714 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7500 0.0702 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8145 0.0701 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7544 0.0713 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7275 0.0717 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7627 0.0706 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7750 0.0710 sec/batch
# Nearest to american: americans, entoprocta, deol, mrc, brooklynites, hispanic, wrestler, cueing,
# Nearest to these: are, the, known, as, other, in, to, more,
# Nearest to than: more, although, it, in, much, widely, have, less,
# Nearest to united: states, nations, western, testify, is, cdb, preamble, japonic,
# Nearest to four: three, one, two, six, eight, five, zero, nine,
# Nearest to had: later, were, came, became, could, already, remained, although,
# Nearest to been: have, since, has, though, came, was, known, researchers,
# Nearest to th: century, rd, late, early, this, nfl, according, afc,
# Nearest to except: vlaams, forms, mercy, sihanoukville, kaunda, almost, displaying, flooded,
# Nearest to test: cricinfo, matches, tests, cricket, galveston, testing, cricketing, distributions,
# Nearest to http: www, htm, html, shtml, edu, geocities, org, appleseed,
# Nearest to discovered: discovery, jupiter, som, mariners, eruption, proxies, comets, dutchman,
# Nearest to something: backtracking, oath, does, das, misspelling, get, csa, thinks,
# Nearest to existence: fornax, watcher, not, emancipation, clifton, sudanese, liam, triumphant,
# Nearest to liberal: democrats, democrat, incumbent, conservative, class, progressive, nr, alde,
# Nearest to issue: correlating, comics, lizzie, methuen, vastly, gibi, eurosceptics, frontman,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7865 0.0726 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7796 0.0714 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7789 0.0710 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7671 0.0704 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7771 0.0708 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7930 0.0711 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7773 0.0717 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7868 0.0714 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7742 0.0715 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7797 0.0714 sec/batch
# Nearest to american: americans, entoprocta, brooklynites, deol, mrc, hispanic, cueing, laird,
# Nearest to these: are, the, as, in, known, other, to, more,
# Nearest to than: more, in, although, have, it, much, less, but,
# Nearest to united: states, nations, is, presidents, testify, cdb, kingdom, carbonation,
# Nearest to four: three, two, one, six, five, eight, seven, zero,
# Nearest to had: later, came, became, were, remained, already, could, was,
# Nearest to been: have, has, since, though, the, that, but, for,
# Nearest to th: century, rd, late, early, this, nfl, rematch, afc,
# Nearest to except: vlaams, forms, almost, plucking, interchangeable, kaunda, mercy, displaying,
# Nearest to test: cricinfo, matches, tests, cricket, galveston, phy, distributions, cricketing,
# Nearest to http: www, htm, html, shtml, edu, geocities, org, appleseed,
# Nearest to discovered: discovery, som, jupiter, mariners, eruption, proxies, dutchman, comets,
# Nearest to something: backtracking, oath, misspelling, get, das, periphrastic, ojibwe, does,
# Nearest to existence: fornax, triumphant, sudanese, watcher, emancipation, not, clifton, smarta,
# Nearest to liberal: democrats, democrat, incumbent, class, conservative, nr, alde, starve,
# Nearest to issue: correlating, comics, methuen, lizzie, vastly, recognized, commissioner, gibi,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7972 0.0730 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8047 0.0716 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8943 0.0688 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8409 0.0700 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8210 0.0695 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7556 0.0707 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7161 0.0712 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7768 0.0715 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6848 0.0720 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8005 0.0714 sec/batch
# Nearest to american: americans, deol, hispanic, wrestler, entoprocta, mrc, laird, brooklynites,
# Nearest to these: are, the, as, other, known, in, various, standardized,
# Nearest to than: more, although, in, much, widely, have, less, it,
# Nearest to united: states, nations, is, presidents, cvn, warship, kingdom, western,
# Nearest to four: three, one, two, six, eight, five, zero, nine,
# Nearest to had: later, became, came, were, remained, could, already, although,
# Nearest to been: have, has, since, though, but, was, found, came,
# Nearest to th: century, rd, late, this, early, according, today, nfl,
# Nearest to except: vlaams, forms, kaunda, almost, mercy, interchangeable, sihanoukville, eleven,
# Nearest to test: cricinfo, tests, matches, cricket, galveston, testing, mathcal, cricketing,
# Nearest to http: www, htm, html, edu, shtml, geocities, org, appleseed,
# Nearest to discovered: discovery, som, jupiter, eruption, mariners, proxies, dutchman, arcturus,
# Nearest to something: backtracking, does, misspelling, oath, periphrastic, get, das, csa,
# Nearest to existence: fornax, emancipation, not, triumphant, sudanese, clifton, vald, smarta,
# Nearest to liberal: democrat, democrats, incumbent, nr, conservative, class, alde, progressive,
# Nearest to issue: correlating, comics, lizzie, methuen, vastly, gibi, recognized, eurosceptics,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7933 0.0727 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7541 0.0717 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
